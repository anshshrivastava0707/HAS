# %% [markdown]
# # Collecting and preparing data
# ## 1. Collecting data from the internet
# ### 1.1 Web scraping
# The internet contains a wealth of data for your Natural Language Processing (NLP) projects. However, the data are usually not ready to be used for NLP projects, as they are not packaged in word document or spreadsheet that can be easily downloadable and further processed. Therefore, we have to learn to collect and process our own data.
#
# In this exercise, we will learn how to collect raw data from websites using a process known as 'web scraping'. We will build a web scraper that will collect information websites of your choice!

# %% [markdown]
# ### 1.1.1 Importing required libraries/ packages
# First, we import the packages that are required:
# - The `requests` package allows our python script to communicate with websites and to 'request' information from those sites.
# - The beautiful soup package, also known as `bs4` takes the raw information from the websites and provides helpful functions to extract information.

# %%
import requests
import bs4

print ("You have successfully imported requests version "+requests.__version__)
print ("You have successfully imported beautifulsoup version "+bs4.__version__)
# Out:
# You have successfully imported requests version 2.28.1
# You have successfully imported beautifulsoup version 4.11.1

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# Yay! Your packages are imported! Now, we are ready to start scraping some websites!

# %% [markdown]
# ### 1.1.2 Finding out information about a website
#
# Now, visit https://en.wikipedia.org/wiki/Jupiter to have a look at the contents of the page.
#
# Once the page is shown, press **ctrl-shift-i (or F12) to look at the HTML of the site.**
# *Note: HTML stands for Hypertext Markup Language and it is a way for your computer browser (like chrome, internet explorer, safari) to understand how information should be displayed.
#
# When you visit a website, your computer uses HTML to send a request (called the 'GET' request) to the internet and waits for a response. The response eventually comes with a response code, and possibly the information requested which is then displayed on your computer browser.

# %% [markdown]
# ### Task: Visit [https://en.wikipedia.org/wiki/Jupiter](https://en.wikipedia.org/wiki/Jupiter) and press ctrl-shift-i (or F12) now!

# %% [markdown]
# Pay close attention to anything you see within < angular brackets >. These tags tell the browser where and how to display the information contained within. Tags are used to identify sections of the web page, and we will be using these tags later to locate pieces of information we are interested in.
#
# ### Task: Can you identify the various tags by looking at the HTML code?
#
# Use the `requests.get()` function to call on the website. The `request.get()` function sends a 'GET' request to the website address and attempts to retrieve a response. The `request.get()` function should return 'Response [200]'. This means that we have successfully received information from the site.

# %%
base_url = 'https://en.wikipedia.org/wiki/Jupiter'
r = requests.get(base_url)
r
# Out:
# <Response [200]>

# %% [markdown]
# ### Task: Try changing the base_url from 'https://en.wikipedia.org/wiki/Jupiter' to 'https://en.wikipedia.org/wiki/Jus21'.
# What did the response code become?
#
# These codes can help in troubleshooting and solving connection problems, but now, we just need to know that a response of 200 means that your GET request was successful!
#
# <em> In case the link is not working for you, you may get a `<Response [404]>` from the code above </em>
#
# Connection establised! We have access!

# %%
base_url= 'https://en.wikipedia.org/wiki/Jus21'
r = requests.get(base_url)
r
# Out:
# <Response [404]>

# %% [markdown]
# ### 1.1.3 Using beautifulsoup to get data from websites
#
# Now we can use `bs4` to read the outputs from our request.
#
# Beautiful Soup is a Python library for getting data out of HTML, XML, and other markup languages.
# *Note: This section of the Jupyter Notebook is written in 'markup' format.
#
# Much like our browser, bs4 is able to understand HTML and to read the < tags >;
#
# See the code below!

# %%
#`r.text` contains the raw HTML returned when we made our GET request earlier. 
#`'html5lib'` tells BeautifulSoup that it is reading HTML information. 
soup = bs4.BeautifulSoup(r.text,'html.parser')

# %% [markdown]
# Essentially, we are taking the raw response from the GET request, and asking BeautifulSoup to read and understand the response, and store all of this as your variable `soup`!

# %% [markdown]
# ### 1.1.4 Using beautifulsoup to search for specific tags
#
# This is where it gets interesting. BeautifulSoup can be used to search for specific tags.
#
# Let's use beautifulsoup to look for all the headings within the Wikipedia website!

# %%
headers = []
for u in soup.findAll("h3"):
    headers.append(u.text)
    print(u.text)
# Out:
# Composition
# Size and mass
# Internal structure
# Atmosphere
# Magnetosphere
# Planetary rings
# Pre-telescopic research
# Ground-based telescope research
# Space-based telescope research
# Radiotelescope research
# Exploration
# Galilean moons
# Classification
# Impacts

# %% [markdown]
# In this code snippet, we find all `<h3>` tags. We then loop through each tag found and extract the text by using the .
#
# *Note: The `<h3>` tag defines a [header](https://www.w3docs.com/learn-html/html-header-tag.html), which defines the heading for the text to follow. To differentiate `<h3>` tags appearing in different locations, they can be 'named' with a `class=tag-name`. In this exercise, we are searching for headers `<h3>` without any classes.

# %% [markdown]
# Let us now see if we have managed to collect all the links in the `headers`. Show the variable headers and check if the information has been added into this variable!

# %%
# your code here
headers
# Out:
# ['Composition',
#  'Size and mass',
#  'Internal structure',
#  'Atmosphere',
#  'Magnetosphere',
#  'Planetary rings',
#  'Pre-telescopic research',
#  'Ground-based telescope research',
#  'Space-based telescope research',
#  'Radiotelescope research',
#  'Exploration',
#  'Galilean moons',
#  'Classification',
#  'Impacts']

# %% [markdown]
# Have you noticed anything odd about the headers in the list? Some of the entries in the list are not relevant. And this is because some of the headers from the toolbar are also being included in the list. Let us remove those.

# %%
print(len(headers))
i = len(headers) - 1
counter = 0
while counter <= i:
    if headers[counter].startswith('\n'):
        headers.pop(counter)
        counter -= 1
    counter += 1
    i = len(headers) -1
print(headers)
# Out:
# 14
# ['Composition', 'Size and mass', 'Internal structure', 'Atmosphere', 'Magnetosphere', 'Planetary rings', 'Pre-telescopic research', 'Ground-based telescope research', 'Space-based telescope research', 'Radiotelescope research', 'Exploration', 'Galilean moons', 'Classification', 'Impacts']

# %% [markdown]
# Now, we will extract the paragraph text of each heading by looping through the paragraph tags that come after each header. Let us see how it is done for one header and you can then do it for all the headers of your choice.
#
# Using the same method as before, visit the first link and press F12 to view page source. Select the element containing the main text and you will be able to see the element source on the panel. Note that the text is surrounded by `<p>` tags.We will be using this information to extract the text soon. Come, do that now!
#
# Notice that on this page, the information is stored within a `<p>` tag. We want to find all paragraphs , so we look for `<p>`  tags, and we call `.get_text()` to retrieve the actual words!

# %%
r = requests.get(base_url)
soup = bs4.BeautifulSoup(r.text,'html.parser')
deet = soup.find('h3', text = headers[0]) # Search for div tags of class 'entry-content content'
para = deet.find_next_sibling('p') # Within these tags, find all p tags
print(para.get_text())
# Out:
# By mass, Jupiter's atmosphere is approximately 76% hydrogen and 24% helium, though, because helium atoms are more massive than hydrogen molecules, Jupiter's upper atmosphere is about 90% hydrogen and 10% helium by volume.[41] The atmosphere also contains trace amounts of methane, water vapour, ammonia, and silicon-based compounds. There are also fractional amounts of carbon, ethane, hydrogen sulfide, neon, oxygen, phosphine, and sulfur. The outermost layer of the atmosphere contains crystals of frozen ammonia. Through infrared and ultraviolet measurements, trace amounts of benzene and other hydrocarbons have also been found.[42] The interior of Jupiter contains denser materials—by mass it is roughly 71% hydrogen, 24% helium, and 5% other elements.[43][44]

# %% [markdown]
# In the above code we use the `find_next_sibling` function to get the next paragraph tag that comes after the header labelled "Composition". Notice in the above code snippet how the we only get one paragraph as a result. But if you take a look once again at the [link](https://en.wikipedia.org/wiki/Jupiter), you will find that there are 3 paragraphs in the "Composition" header. How can we get all of the paragraphs?
#
# The solution is to loop through the next siblings. The rules we have set are as follows:
#
# - If the next sibling is an `<h2>` or `<h3>` tag then go to the next header.
#
# - If the tag is a `<p>` tag, only then should you print the text.
#
# Take a look at the code snippet below to see the results.

# %%
r = requests.get(base_url)
soup = bs4.BeautifulSoup(r.text,'html.parser')
deet = soup.find('h3', text = headers[1]) # Search for div tags of class 'entry-content content'
print(headers[1])
for para in deet.find_next_siblings(): # Within these tags, find all p tags
    if para.name == "h2" or para.name == "h3":
        break
    elif para.name == "p":
        print(para.get_text())
# Out:
# Size and mass
# Jupiter's mass is 318 times that of Earth;[2] 2.5 times that of all the other planets in the Solar System combined. It is so massive that its barycentre with the Sun lies above the Sun's surface at 1.068 solar radii from the Sun's centre.[49] [50]: 6  Jupiter's radius is about one tenth the radius of the Sun,[51] and its mass is one thousandth the mass of the Sun, as the densities of the two bodies are similar.[52] A "Jupiter mass" (MJ or MJup) is often used as a unit to describe masses of other objects, particularly extrasolar planets and brown dwarfs. For example, the extrasolar planet HD 209458 b has a mass of 0.69 MJ, while the brown dwarf Gliese 229 b has a mass of 60.4 MJ.[53][54]
#
# Theoretical models indicate that if Jupiter had over 40% more mass, the interior would be so compressed that its volume would decrease despite the increasing amount of matter. For smaller changes in its mass, the radius would not change appreciably.[55] As a result, Jupiter is thought to have about as large a diameter as a planet of its composition and evolutionary history can achieve.[56] The process of further shrinkage with increasing mass would continue until appreciable stellar ignition was achieved.[57] Although Jupiter would need to be about 75 times more massive to fuse hydrogen and become a star,[58] its diameter is sufficient as the smallest red dwarf may be only slightly larger in radius than Saturn.[59]
#
# Jupiter radiates more heat than it receives through solar radiation, due to the Kelvin–Helmholtz mechanism within its contracting interior.[60]: 30 [61] This process causes Jupiter to shrink by about 1 mm (0.039 in)/yr.[62][63] At the time of its formation, Jupiter was hotter and was about twice its current diameter.[64]

# %% [markdown]
# Now that we can see how it is possible to extract text from a web page, it is your turn!
# ### Task 1: Write a function that can loop through the entries in `headers`
#
# Extract the contents of each header. Combine all the text into a variable "all_para"

# %%
r = requests.get(base_url)
all_para = ""
soup = bs4.BeautifulSoup(r.text,'html.parser')
for i in range(len(headers)):
    deet = soup.find('h3', text = headers[i]) # Search for div tags of class 'entry-content content'
    for para in deet.find_next_siblings(): # Within these tags, find all p tags
        if para.name == "h2" or para.name == "h3":
            break
        elif para.name == "p":
            all_para += para.get_text()
            all_para += '\n'

# %%
print(all_para)
# Out:
# By mass, Jupiter's atmosphere is approximately 76% hydrogen and 24% helium, though, because helium atoms are more massive than hydrogen molecules, Jupiter's upper atmosphere is about 90% hydrogen and 10% helium by volume.[41] The atmosphere also contains trace amounts of methane, water vapour, ammonia, and silicon-based compounds. There are also fractional amounts of carbon, ethane, hydrogen sulfide, neon, oxygen, phosphine, and sulfur. The outermost layer of the atmosphere contains crystals of frozen ammonia. Through infrared and ultraviolet measurements, trace amounts of benzene and other hydrocarbons have also been found.[42] The interior of Jupiter contains denser materials—by mass it is roughly 71% hydrogen, 24% helium, and 5% other elements.[43][44]
#
# The atmospheric proportions of hydrogen and helium are close to the theoretical composition of the primordial solar nebula. Neon in the upper atmosphere only consists of 20 parts per million by mass, which is about a tenth as abundant as in the Sun.[45] Helium is also reduced to about 80% of the Sun's helium composition. This depletion is a result of precipitation of these elements as helium-rich droplets, a process that happens deep in the interior of the planet.[46][47]
#
# Based on spectroscopy, Saturn is thought to be similar in composition to Jupiter, but the other giant planets Uranus and Neptune have relatively less hydrogen and helium and relatively more of the next most common elements, including oxygen, carbon, nitrogen, and sulfur.[48] Those planets are known as ice giants, because the majority of their volatile compounds are in solid form.
#
# Jupiter's mass is 318 times that of Earth;[2] 2.5 times that of all the other planets in the Solar System combined. It is so massive that its barycentre with the Sun lies above the Sun's surface at 1.068 solar radii from the Sun's centre.[49] [50]: 6  Jupiter's radius is about one tenth the radius of the Sun,[51] and its mass is one thousandth the mass of the Sun, as the densities of the two bodies are similar.[52] A "Jupiter mass" (MJ or MJup) is often used as a unit to describe masses of other objects, particularly extrasolar planets and brown dwarfs. For example, the extrasolar planet HD 209458 b has a mass of 0.69 MJ, while the brown dwarf Gliese 229 b has a mass of 60.4 MJ.[53][54]
#
# Theoretical models indicate that if Jupiter had over 40% more mass, the interior would be so compressed that its volume would decrease despite the increasing amount of matter. For smaller changes in its mass, the radius would not change appreciably.[55] As a result, Jupiter is thought to have about as large a diameter as a planet of its composition and evolutionary history can achieve.[56] The process of further shrinkage with increasing mass would continue until appreciable stellar ignition was achieved.[57] Although Jupiter would need to be about 75 times more massive to fuse hydrogen and become a star,[58] its diameter is sufficient as the smallest red dwarf may be only slightly larger in radius than Saturn.[59]
#
# Jupiter radiates more heat than it receives through solar radiation, due to the Kelvin–Helmholtz mechanism within its contracting interior.[60]: 30 [61] This process causes Jupiter to shrink by about 1 mm (0.039 in)/yr.[62][63] At the time of its formation, Jupiter was hotter and was about twice its current diameter.[64]
#
# Before the early 21st century, most scientists proposed one of two scenarios for the formation of Jupiter. If the planet accreted first as a solid body, it would consist of a dense core, a surrounding layer of liquid metallic hydrogen (with some helium) extending outward to about 80% of the radius of the planet,[65] and an outer atmosphere consisting primarily of molecular hydrogen.[63] Alternatively, if the planet collapsed directly from the gaseous protoplanetary disk, it was expected to completely lack a core, consisting instead of denser and denser fluid (predominantly molecular and metallic hydrogen) all the way to the centre. Data from the Juno mission showed that Jupiter has a diffuse core that mixes into its mantle.[66][67][68] This mixing process could have arisen during formation, while the planet accreted solids and gases from the surrounding nebula.[69] Alternatively, it could have been caused by an impact from a planet of about ten Earth masses a few million years after Jupiter's formation, which would have disrupted an originally solid Jovian core.[70][71] It is estimated that the core takes up 30–50% of the planet's radius, and contains heavy elements with a combined mass 7–25 times the Earth.[72]
#
# Outside the layer of metallic hydrogen lies a transparent interior atmosphere of hydrogen. At this depth, the pressure and temperature are above molecular hydrogen's critical pressure of 1.3 MPa and critical temperature of 33 K (−240.2 °C; −400.3 °F).[73] In this state, there are no distinct liquid and gas phases—hydrogen is said to be in a supercritical fluid state. The hydrogen and helium gas extending downward from the cloud layer gradually transitions to a liquid in deeper layers, possibly resembling something akin to an ocean of liquid hydrogen and other supercritical fluids.[60]: 22 [74][75][76] Physically, the gas gradually becomes hotter and denser as depth increases.[77][78]
#
# Rain-like droplets of helium and neon precipitate downward through the lower atmosphere, depleting the abundance of these elements in the upper atmosphere.[46][79] Calculations suggest that helium drops separate from metallic hydrogen at a radius of 60,000 km (37,000 mi) (11,000 km (6,800 mi) below the cloud tops) and merge again at 50,000 km (31,000 mi) (22,000 km (14,000 mi) beneath the clouds).[80] Rainfalls of diamonds have been suggested to occur, as well as on Saturn[81] and the ice giants Uranus and Neptune.[82]
#
# The temperature and pressure inside Jupiter increase steadily inward as the heat of planetary formation can only escape by convection.[47] At a surface depth where the atmospheric pressure level is 1 bar (0.10 MPa), the temperature is around 165 K (−108 °C; −163 °F). The region where supercritical hydrogen changes gradually from a molecular fluid to a metallic fluid spans pressure ranges of 50–400 GPa with temperatures of 5,000–8,400 K (4,730–8,130 °C; 8,540–14,660 °F), respectively. The temperature of Jupiter's diluted core is estimated to be 20,000 K (19,700 °C; 35,500 °F) with a pressure of around 4,000 GPa.[83]
#
# The atmosphere of Jupiter extends to a depth of 3,000 km (2,000 mi) below the cloud layers.[83]
#
# Jupiter is perpetually covered with clouds of ammonia crystals, which may contain ammonium hydrosulfide as well.[84] The clouds are located in the tropopause layer of the atmosphere, forming bands at different latitudes, known as tropical regions. These are subdivided into lighter-hued zones and darker belts. The interactions of these conflicting circulation patterns cause storms and turbulence. Wind speeds of 100 metres per second (360 km/h; 220 mph) are common in zonal jet streams.[85] The zones have been observed to vary in width, colour and intensity from year to year, but they have remained stable enough for scientists to name them.[50]: 6
#
# The cloud layer is about 50 km (31 mi) deep, and consists of at least two decks of ammonia clouds: a thin clearer region on top with a thick lower deck. There may be a thin layer of water clouds underlying the ammonia clouds, as suggested by flashes of lightning detected in the atmosphere of Jupiter.[86] These electrical discharges can be up to a thousand times as powerful as lightning on Earth.[87] The water clouds are assumed to generate thunderstorms in the same way as terrestrial thunderstorms, driven by the heat rising from the interior.[88] The Juno mission revealed the presence of "shallow lightning" which originates from ammonia-water clouds relatively high in the atmosphere.[89] These discharges carry "mushballs" of water-ammonia slushes covered in ice, which fall deep into the atmosphere.[90] Upper-atmospheric lightning has been observed in Jupiter's upper atmosphere, bright flashes of light that last around 1.4 milliseconds. These are known as "elves" or "sprites" and appear blue or pink due to the hydrogen.[91][92]
#
# The orange and brown colours in the clouds of Jupiter are caused by upwelling compounds that change colour when they are exposed to ultraviolet light from the Sun. The exact makeup remains uncertain, but the substances are thought to be made up of phosphorus, sulfur or possibly hydrocarbons.[60]: 39 [93] These colourful compounds, known as chromophores, mix with the warmer clouds of the lower deck. The light-coloured zones are formed when rising convection cells form crystallising ammonia that hides the chromophores from view.[94]
#
# Jupiter has a low axial tilt, thus making it that the poles always receive less solar radiation than the planet's equatorial region. Convection within the interior of the planet transports energy to the poles, balancing out the temperatures at the cloud layer.[50]: 54
#
# A well-known feature of Jupiter is the Great Red Spot,[95] a persistent anticyclonic storm located 22° south of the equator. It is known to have existed since at least 1831,[96] and possibly since 1665.[97][98] Images by the Hubble Space Telescope have shown two more "red spots" adjacent to the Great Red Spot.[99][100] The storm is visible through Earth-based telescopes with an aperture of 12 cm or larger.[101] The oval object rotates counterclockwise, with a period of about six days.[102] The maximum altitude of this storm is about 8 km (5 mi) above the surrounding cloud tops.[103] The Spot's composition and the source of its red colour remain uncertain, although photodissociated ammonia reacting with acetylene is a likely explanation.[104]
#
# The Great Red Spot is larger than the Earth.[105] Mathematical models suggest that the storm is stable and will be a permanent feature of the planet.[106] However, it has significantly decreased in size since its discovery. Initial observations in the late 1800s showed it to be approximately 41,000 km (25,500 mi) across. By the time of the Voyager flybys in 1979, the storm had a length of 23,300 km (14,500 mi) and a width of approximately 13,000 km (8,000 mi).[107] Hubble observations in 1995 showed it had decreased in size to 20,950 km (13,020 mi), and observations in 2009 showed the size to be 17,910 km (11,130 mi). As of 2015[update], the storm was measured at approximately 16,500 by 10,940 km (10,250 by 6,800 mi),[107] and was decreasing in length by about 930 km (580 mi) per year.[105][108] In October 2021, a Juno flyby mission measured the depth of the Great Red Spot, putting it at around 300–500 kilometres (190–310 mi).[109]
#
# Juno missions show that there are several polar cyclone groups at Jupiter's poles. The northern group contains nine cyclones, with a large one in the centre and eight others around it, while its southern counterpart also consists of a centre vortex but is surrounded by five large storms and a single smaller one for a total of 7 storms.[110][111] These polar structures are caused by the turbulence in Jupiter's atmosphere and can be compared with the hexagon at Saturn's north pole.
#
# In 2000, an atmospheric feature formed in the southern hemisphere that is similar in appearance to the Great Red Spot, but smaller. This was created when smaller, white oval-shaped storms merged to form a single feature—these three smaller white ovals were formed in 1939–1940. The merged feature was named Oval BA. It has since increased in intensity and changed from white to red, earning it the nickname "Little Red Spot".[112][113]
#
# In April 2017, a "Great Cold Spot" was discovered in Jupiter's thermosphere at its north pole. This feature is 24,000 km (15,000 mi) across, 12,000 km (7,500 mi) wide, and 200 °C (360 °F) cooler than surrounding material. While this spot changes form and intensity over the short term, it has maintained its general position in the atmosphere for more than 15 years. It may be a giant vortex similar to the Great Red Spot, and appears to be quasi-stable like the vortices in Earth's thermosphere. This feature may be formed by interactions between charged particles generated from Io and the strong magnetic field of Jupiter, resulting in a redistribution of heat flow.[114]
#
# Jupiter's magnetic field is the strongest of any planet in the Solar System,[94] with a dipole moment of 4.170 gauss (0.4170 mT) that is tilted at an angle of 10.31° to the pole of rotation. The surface magnetic field strength varies from 2 gauss (0.20 mT) up to 20 gauss (2.0 mT).[115] This field is thought to be generated by eddy currents—swirling movements of conducting materials—within the liquid, metallic hydrogen core. At about 75 Jupiter radii from the planet, the interaction of the magnetosphere with the solar wind generates a bow shock. Surrounding Jupiter's magnetosphere is a magnetopause, located at the inner edge of a magnetosheath—a region between it and the bow shock. The solar wind interacts with these regions, elongating the magnetosphere on Jupiter's lee side and extending it outward until it nearly reaches the orbit of Saturn. The four largest moons of Jupiter all orbit within the magnetosphere, which protects them from the solar wind.[60]: 69
#
# The volcanoes on the moon Io emit large amounts of sulfur dioxide, forming a gas torus along its orbit. The gas is ionized in Jupiter's magnetosphere, producing sulfur and oxygen ions. They, together with hydrogen ions originating from the atmosphere of Jupiter, form a plasma sheet in Jupiter's equatorial plane. The plasma in the sheet co-rotates with the planet, causing deformation of the dipole magnetic field into that of a magnetodisk. Electrons within the plasma sheet generate a strong radio signature, with short, superimposed bursts in the range of 0.6–30 MHz that are detectable from Earth with consumer-grade shortwave radio receivers.[116][117] As Io moves through this torus, the interaction generates Alfvén waves that carry ionized matter into the polar regions of Jupiter. As a result, radio waves are generated through a cyclotron maser mechanism, and the energy is transmitted out along a cone-shaped surface. When Earth intersects this cone, the radio emissions from Jupiter can exceed the radio output of the Sun.[118]
#
# Jupiter has a faint planetary ring system composed of three main segments: an inner torus of particles known as the halo, a relatively bright main ring, and an outer gossamer ring.[119] These rings appear to be made of dust, whereas Saturn's rings are made of ice.[60]: 65  The main ring is most likely made out of material ejected from the satellites Adrastea and Metis, which is drawn into Jupiter because of the planet's strong gravitational influence. New material is added by additional impacts.[120] In a similar way, the moons Thebe and Amalthea are believed to produce the two distinct components of the dusty gossamer ring.[120] There is evidence of a fourth ring that may consist of collisional debris from Amalthea that is strung along the same moon's orbit.[121]
#
# Observation of Jupiter dates back to at least the Babylonian astronomers of the 7th or 8th century BC.[134] The ancient Chinese knew Jupiter as the "Suì Star" (Suìxīng 歲星) and established their cycle of 12 earthly branches based on the approximate number of years it takes Jupiter to rotate around the Sun; the Chinese language still uses its name (simplified as 歲) when referring to years of age. By the 4th century BC, these observations had developed into the Chinese zodiac,[135] and each year became associated with a Tai Sui star and god controlling the region of the heavens opposite Jupiter's position in the night sky. These beliefs survive in some Taoist religious practices and in the East Asian zodiac's twelve animals. The Chinese historian Xi Zezong has claimed that Gan De, an ancient Chinese astronomer,[136] reported a small star "in alliance" with the planet,[137] which may indicate a sighting of one of Jupiter's moons with the unaided eye. If true, this would predate Galileo's discovery by nearly two millennia.[138][139]
#
# A 2016 paper reports that trapezoidal rule was used by Babylonians before 50 BCE for integrating the velocity of Jupiter along the ecliptic.[140] In his 2nd century work the Almagest, the Hellenistic astronomer Claudius Ptolemaeus constructed a geocentric planetary model based on deferents and epicycles to explain Jupiter's motion relative to Earth, giving its orbital period around Earth as 4332.38 days, or 11.86 years.[141]
#
# In 1610, Italian polymath Galileo Galilei discovered the four largest moons of Jupiter (now known as the Galilean moons) using a telescope. This is thought to be the first telescopic observation of moons other than Earth's. Just one day after Galileo, Simon Marius independently discovered moons around Jupiter, though he did not publish his discovery in a book until 1614.[142] It was Marius's names for the major moons, however, that stuck: Io, Europa, Ganymede, and Callisto. The discovery was a major point in favour of Copernicus' heliocentric theory of the motions of the planets; Galileo's outspoken support of the Copernican theory led to him being tried and condemned by the Inquisition.[143]
#
# During the 1660s, Giovanni Cassini used a new telescope to discover spots and colourful bands in Jupiter's atmosphere, observe that the planet appeared oblate, and estimate its rotation period.[144] In 1692, Cassini noticed that the atmosphere undergoes differential rotation.[145]
#
# The Great Red Spot may have been observed as early as 1664 by Robert Hooke and in 1665 by Cassini, although this is disputed. The pharmacist Heinrich Schwabe produced the earliest known drawing to show details of the Great Red Spot in 1831.[146] The Red Spot was reportedly lost from sight on several occasions between 1665 and 1708 before becoming quite conspicuous in 1878.[147] It was recorded as fading again in 1883 and at the start of the 20th century.[148]
#
# Both Giovanni Borelli and Cassini made careful tables of the motions of Jupiter's moons, which allowed predictions of when the moons would pass before or behind the planet. By the 1670s, Cassini observed that when Jupiter was on the opposite side of the Sun from Earth, these events would occur about 17 minutes later than expected. Ole Rømer deduced that light does not travel instantaneously (a conclusion that Cassini had earlier rejected),[44] and this timing discrepancy was used to estimate the speed of light.[149][150]
#
# In 1892, E. E. Barnard observed a fifth satellite of Jupiter with the 36-inch (910 mm) refractor at Lick Observatory in California. This moon was later named Amalthea.[151] It was the last planetary moon to be discovered directly by a visual observer through a telescope.[152] An additional eight satellites were discovered before the flyby of the Voyager 1 probe in 1979.[e]
#
# In 1932, Rupert Wildt identified absorption bands of ammonia and methane in the spectra of Jupiter.[153] Three long-lived anticyclonic features called "white ovals" were observed in 1938. For several decades they remained as separate features in the atmosphere, sometimes approaching each other but never merging. Finally, two of the ovals merged in 1998, then absorbed the third in 2000, becoming Oval BA.[154]
#
# On July 14, 2022, NASA presented images of Jupiter and related areas captured, for the first time, and including infrared views, by the James Webb Space Telescope (JWST).[155]
#
# In 1955, Bernard Burke and Kenneth Franklin discovered that Jupiter emits bursts of radio waves at a frequency of 22.2 MHz.[60]: 36  The period of these bursts matched the rotation of the planet, and they used this information to determine a more precise value for Jupiter's rotation rate. Radio bursts from Jupiter were found to come in two forms: long bursts (or L-bursts) lasting up to several seconds, and short bursts (or S-bursts) lasting less than a hundredth of a second.[156]
#
# Scientists have discovered three forms of radio signals transmitted from Jupiter:
#
# Jupiter has been visited by automated spacecraft since 1973, when the space probe Pioneer 10 passed close enough to Jupiter to send back revelations about its properties and phenomena.[159][160] Missions to Jupiter are accomplished at a cost in energy, which is described by the net change in velocity of the spacecraft, or delta-v. Entering a Hohmann transfer orbit from Earth to Jupiter from low Earth orbit requires a delta-v of 6.3 km/s,[161] which is comparable to the 9.7 km/s delta-v needed to reach low Earth orbit.[162] Gravity assists through planetary flybys can be used to reduce the energy required to reach Jupiter.[163]
#
# Beginning in 1973, several spacecraft have performed planetary flyby manoeuvres that brought them within observation range of Jupiter. The Pioneer missions obtained the first close-up images of Jupiter's atmosphere and several of its moons. They discovered that the radiation fields near the planet were much stronger than expected, but both spacecraft managed to survive in that environment. The trajectories of these spacecraft were used to refine the mass estimates of the Jovian system. Radio occultations by the planet resulted in better measurements of Jupiter's diameter and the amount of polar flattening.[50]: 47 [165]
#
# Six years later, the Voyager missions vastly improved the understanding of the Galilean moons and discovered Jupiter's rings. They also confirmed that the Great Red Spot was anticyclonic. Comparison of images showed that the Spot had changed hue since the Pioneer missions, turning from orange to dark brown. A torus of ionized atoms was discovered along Io's orbital path, which were found to come from erupting volcanoes on the moon's surface. As the spacecraft passed behind the planet, it observed flashes of lightning in the night side atmosphere.[50]: 87 [166]
#
# The next mission to encounter Jupiter was the Ulysses solar probe. In February 1992, it performed a flyby manoeuvre to attain a polar orbit around the Sun. During this pass, the spacecraft studied Jupiter's magnetosphere, although it had no cameras to photograph the planet. The spacecraft passed by Jupiter six years later, this time at a much greater distance.[164]
#
# In 2000, the Cassini probe flew by Jupiter on its way to Saturn, and provided higher-resolution images.[167]
#
# The New Horizons probe flew by Jupiter in 2007 for a gravity assist en route to Pluto.[168] The probe's cameras measured plasma output from volcanoes on Io and studied all four Galilean moons in detail.[169]
#
# The first spacecraft to orbit Jupiter was the Galileo mission, which reached the planet on December 7, 1995.[56] It remained in orbit for over seven years, conducting multiple flybys of all the Galilean moons and Amalthea. The spacecraft also witnessed the impact of Comet Shoemaker–Levy 9 when it collided with Jupiter in 1994. Some of the goals for the mission were thwarted due to a malfunction in Galileo's high-gain antenna.[170]
#
# A 340-kilogram titanium atmospheric probe was released from the spacecraft in July 1995, entering Jupiter's atmosphere on December 7.[56] It parachuted through 150 km (93 mi) of the atmosphere at a speed of about 2,575 km/h (1600 mph)[56] and collected data for 57.6 minutes until the spacecraft was destroyed.[171] The Galileo orbiter itself experienced a more rapid version of the same fate when it was deliberately steered into the planet on September 21, 2003. NASA destroyed the spacecraft in order to avoid any possibility of the spacecraft crashing into and possibly contaminating the moon Europa, which may harbour life.[170]
#
# Data from this mission revealed that hydrogen composes up to 90% of Jupiter's atmosphere.[56] The recorded temperature was more than 300 °C (570 °F) and the windspeed measured more than 644 km/h (>400 mph) before the probes vaporized.[56]
#
# NASA's Juno mission arrived at Jupiter on July 4, 2016 with the goal of studying the planet in detail from a polar orbit. The spacecraft was originally intended to orbit Jupiter thirty-seven times over a period of twenty months.[172][66][173] During the mission, the spacecraft will be exposed to high levels of radiation from Jupiter's magnetosphere, which may cause future failure of certain instruments.[174] On August 27, 2016, the spacecraft completed its first fly-by of Jupiter and sent back the first-ever images of Jupiter's north pole.[175]
#
# Juno completed 12 orbits before the end of its budgeted mission plan, ending July 2018.[176] In June of that year, NASA extended the mission operations plan to July 2021, and in January of that year the mission was extended to September 2025 with four lunar flybys: one of Ganymede, one of Europa, and two of Io.[177][178] When Juno reaches the end of the mission, it will perform a controlled deorbit and disintegrate into Jupiter's atmosphere. This will avoid the risk of collision with Jupiter's moons.[179][180]
#
# There is great interest in missions to study Jupiter's larger icy moons, which may have subsurface liquid oceans.[181] Funding difficulties have delayed progress, causing NASA's JIMO (Jupiter Icy Moons Orbiter) to be cancelled in 2005.[182] A subsequent proposal was developed for a joint NASA/ESA mission called EJSM/Laplace, with a provisional launch date around 2020. EJSM/Laplace would have consisted of the NASA-led Jupiter Europa Orbiter and the ESA-led Jupiter Ganymede Orbiter.[183] However, the ESA formally ended the partnership in April 2011, citing budget issues at NASA and the consequences on the mission timetable. Instead, ESA planned to go ahead with a European-only mission to compete in its L1 Cosmic Vision selection.[184] These plans have been realized as the European Space Agency's Jupiter Icy Moon Explorer (JUICE), launched on April 14, 2023,[185] followed by NASA's Europa Clipper mission, scheduled for launch in 2024.[186]
#
# Other proposed missions include the Chinese National Space Administration's Tianwen-4 mission which aims to launch an orbiter to the Jovian system and possibly Callisto around 2035,[187] and CNSA's Interstellar Express[188] and NASA's Interstellar Probe,[189] which would both use Jupiter's gravity to help them reach the edges of the heliosphere.
#
# The moons discovered by Galileo—Io, Europa, Ganymede, and Callisto—are among the largest in the Solar System. The orbits of Io, Europa, and Ganymede form a pattern known as a Laplace resonance; for every four orbits that Io makes around Jupiter, Europa makes exactly two orbits and Ganymede makes exactly one. This resonance causes the gravitational effects of the three large moons to distort their orbits into elliptical shapes, because each moon receives an extra tug from its neighbours at the same point in every orbit it makes. The tidal force from Jupiter, on the other hand, works to circularize their orbits.[192]
#
# The eccentricity of their orbits causes regular flexing of the three moons' shapes, with Jupiter's gravity stretching them out as they approach it and allowing them to spring back to more spherical shapes as they swing away. The friction created by this tidal flexing generates heat in the interior of the moons.[193] This is seen most dramatically in the volcanic activity of Io (which is subject to the strongest tidal forces),[193] and to a lesser degree in the geological youth of Europa's surface, which indicates recent resurfacing of the moon's exterior.[194]
#
# Jupiter's moons were traditionally classified into four groups of four, based on their similar orbital elements.[195] This picture has been complicated by the discovery of numerous small outer moons since 1999. Jupiter's moons are currently divided into several different groups, although there are several moons which are not part of any group.[196]
#
# The eight innermost regular moons, which have nearly circular orbits near the plane of Jupiter's equator, are thought to have formed alongside Jupiter, whilst the remainder are irregular moons and are thought to be captured asteroids or fragments of captured asteroids. The irregular moons within each group may have a common origin, perhaps as a larger moon or captured body that broke up.[197][198]
#
# Jupiter has been called the Solar System's vacuum cleaner[207] because of its immense gravity well and location near the inner Solar System. There are more impacts on Jupiter, such as comets, than on any other planet in the Solar System.[208] For example, Jupiter experiences about 200 times more asteroid and comet impacts than Earth.[56] In the past, scientists believed that Jupiter partially shielded the inner system from cometary bombardment.[56] However, computer simulations in 2008 suggest that Jupiter does not cause a net decrease in the number of comets that pass through the inner Solar System, as its gravity perturbs their orbits inward roughly as often as it accretes or ejects them.[209] This topic remains controversial among scientists, as some think it draws comets towards Earth from the Kuiper belt, while others believes that Jupiter protects Earth from the Oort cloud.[210]
#
# In July 1994, the Comet Shoemaker–Levy 9 comet collided with Jupiter.[211][212] The impacts were closely observed by observatories around the world, including the Hubble Space Telescope and Galileo spacecraft.[213][214][215][216] The event was widely covered by the media.[217]
#
# Surveys of early astronomical records and drawings produced eight examples of potential impact observations between 1664 and 1839. However, a 1997 review determined that these observations had little or no possibility of being the results of impacts. Further investigation by this team revealed a dark surface feature discovered by astronomer Giovanni Cassini in 1690 may have been an impact scar.[218]

# %% [markdown]
# ### 1.2 Storing data
# Congratulations! You have built your very own scraper and used it to collect data from several webpages. You now need a way to store this data so you do not have to scrape the websites every time you want to access the data. Storing the information collected also preserves the data in the event that the website is taken down or changed.

# %% [markdown]
# ### Task 2: Write code to save your data as a text file.
#
# If you need help, try https://stackoverflow.com/questions/899103/writing-a-list-to-a-file-with-python or searching on your own using any search engine of your choice.
#
# *Note: You will have to create a file object with open(filename). Then use the .write() attribute to write text into the file. See the documentation for writing to file at https://www.guru99.com/reading-and-writing-files-in-python.html

# %%
with open('./wiki.txt', 'wb') as file_handler:
        file_handler.write(all_para.encode('utf8'))

# %% [markdown]
# Great! Now check your file on your directory folder and see if you have the required information captured there

# %% [markdown]
# ### 1.3 Other data sources
# Congratulations! you are now equipped to download text from any website. Do take note that different websites have different html structures, so you will have to modify your code for each site you scrape.
#
# How then can we get alot of data without caring too much on the differences between the websites?
#
# #### How else can we get lots of data?
#
# Fortunately, there are great amount of data that has already been compiled by other people. These files may be saved in a document format such as .csv or .txt which can be easily downloaded with a simple script.
#
# There are sites dedicated to harvesting interesting datasets which can then be easily downloaded by anyone and used for AI.
# Check out where you can get free, processed data for your projects:
# - https://www.figure-eight.com/data-for-everyone/.
# - https://github.com/niderhoff/nlp-datasets
#
# Take a look at some of the datasets and think of things you would like to work on.

# %% [markdown]
# ### Downloading tweet data
# For now, we will be looking at a dataset that captures social media responses in the from of tweets.
#
# This dataset consists of a series of tweets, along with an indication of whether the tweet is relevant to a disaster, or not relevant to a disaster.
#
# How do you think this dataset can be used to train an AI system? How do you think this dataset can be helpful?
#
# Being able to classify tweets will allow us to filter out noise and gain information from useful tweets in real time during an actual disaster. These tweets may contain helpful information on places to avoid, how to help, or how to ask for help.
#
# The code below downloads and saves a .csv file located at `url` using the library `urllib`

# %%
import urllib

url = 'https://sl2files.sustainablelivinglab.org/DatasetSocialMedia-Disaster-tweets-DFE.csv'

csv = urllib.request.urlopen(url).read()
with open('./[Dataset](socialmedia disaster tweets DFE).csv', 'wb') as fx:
    fx.write(csv)

# %% [markdown]
# Great! We've now downloaded our data! Check out the csv file we have just created!
#
# Notice how the dataset is structured.
# What headers do you see?

# %% [markdown]
# ## 2.1 Processing text
# In its raw form, tweets are just strings of text. While humans can easily read and understand strings of text, computers have a much harder time doing so. Therefore, we will have to perform preprocessing on these strings to break them up into a form that our computers can recognize and work on.
#
# Preprocessing the text will also allow us to analyze and visualize the text, and to look for trends and features that your computer will then be able to use to classify your text.
#
# Let us practice using the dataset on tweet disasters.
#
# First, we import the packages we need:
# - The pandas package helps us to load files into our program in a structure called a dataframe
# - The nltk package is the star of the show that allows us to process and visualize text.

# %%
import pandas as pd
import nltk

print ("You have successfully imported pandas version "+pd.__version__)
print ("You have successfully imported nltk version "+nltk.__version__)
# Out:
# You have successfully imported pandas version 1.5.3
# You have successfully imported nltk version 3.7

# %%
# load the csv file that contains the tweets on natural disasters into a pandas dataframe
df_raw = pd.read_csv('./[Dataset](socialmedia disaster tweets DFE).csv', encoding='ISO-8859-1')

print ("You have successfully loaded your csv file")
# Out:
# You have successfully loaded your csv file

# %% [markdown]
# Let us take a quick look at the data!
# using `.head(5)` on a pandas dataframe lets us look at the first 5 lines of the dataframe.

# %%
df_raw.head(5)
# Out:
#    Unnamed: 0   _unit_id  _golden _unit_state  _trusted_judgments  \
# 0           0  778243823     True      golden                 156
# 1           1  778243824     True      golden                 152
# 2           2  778243825     True      golden                 137
# 3           3  778243826     True      golden                 136
# 4           4  778243827     True      golden                 138
#
#   _last_judgment_at choose_one  choose_one:confidence choose_one_gold keyword  \
# 0               NaN   Relevant                 1.0000        Relevant     NaN
# 1               NaN   Relevant                 1.0000        Relevant     NaN
# 2               NaN   Relevant                 1.0000        Relevant     NaN
# 3               NaN   Relevant                 0.9603        Relevant     NaN
# 4               NaN   Relevant                 1.0000        Relevant     NaN
#
#   location                                               text  tweetid  userid
# 0      NaN                 Just happened a terrible car crash      1.0     NaN
# 1      NaN  Our Deeds are the Reason of this #earthquake M...     13.0     NaN
# 2      NaN  Heard about #earthquake is different cities, s...     14.0     NaN
# 3      NaN  there is a forest fire at spot pond, geese are...     15.0     NaN
# 4      NaN             Forest fire near La Ronge Sask. Canada     16.0     NaN

# %% [markdown]
# How would you inspect the first 10 lines of the dataframe? Try it on the code block above!

# %%
df_raw.head(10)
# Out:
#    Unnamed: 0   _unit_id  _golden _unit_state  _trusted_judgments  \
# 0           0  778243823     True      golden                 156
# 1           1  778243824     True      golden                 152
# 2           2  778243825     True      golden                 137
# 3           3  778243826     True      golden                 136
# 4           4  778243827     True      golden                 138
# 5           5  778243828     True      golden                 140
# 6           6  778243831     True      golden                 142
# 7           7  778243832     True      golden                 151
# 8           8  778243833     True      golden                 143
# 9           9  778243834     True      golden                 136
#
#   _last_judgment_at choose_one  choose_one:confidence         choose_one_gold  \
# 0               NaN   Relevant                 1.0000                Relevant
# 1               NaN   Relevant                 1.0000                Relevant
# 2               NaN   Relevant                 1.0000                Relevant
# 3               NaN   Relevant                 0.9603                Relevant
# 4               NaN   Relevant                 1.0000                Relevant
# 5               NaN   Relevant                 1.0000                Relevant
# 6               NaN   Relevant                 1.0000                Relevant
# 7               NaN   Relevant                 1.0000                Relevant
# 8               NaN   Relevant                 1.0000                Relevant
# 9               NaN   Relevant                 0.9606  Relevant\nCan't Decide
#
#   keyword location                                               text  \
# 0     NaN      NaN                 Just happened a terrible car crash
# 1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 2     NaN      NaN  Heard about #earthquake is different cities, s...
# 3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
# 8     NaN      NaN  #RockyFire Update => California Hwy. 20 closed...
# 9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
#
#    tweetid  userid
# 0      1.0     NaN
# 1     13.0     NaN
# 2     14.0     NaN
# 3     15.0     NaN
# 4     16.0     NaN
# 5     17.0     NaN
# 6     18.0     NaN
# 7     19.0     NaN
# 8     20.0     NaN
# 9     21.0     NaN

# %% [markdown]
# The pandas dataframe looks like a spreadsheet, with each column containing a category of data, and each row representing the information from a single tweet.
#
# There are many columns, and we will not worry about those for now. Let us focus our attention on the column where the tweets are stored.
#
# See the dataframe above! Can you tell which column we should inspect to see the tweets? putting the column name in string format inside square brackets lets you select just that column. i.e. `df_raw['column_name']`
#
# ### Task: Try out different columns and see the data included

# %%
df_raw['text'].head()   # helps us to display the first five rows
# Out:
# 0                   Just happened a terrible car crash
# 1    Our Deeds are the Reason of this #earthquake M...
# 2    Heard about #earthquake is different cities, s...
# 3    there is a forest fire at spot pond, geese are...
# 4               Forest fire near La Ronge Sask. Canada
# Name: text, dtype: object

# %% [markdown]
# Let us look at a few random samples of tweets. use .sample() to view the samples.

# %%
list(df_raw['text'].sample())
# Out:
# ['70 years ago today the U.S.  dropped a nuclear weapon on Japan. Here are some articles that share my opinion on that decisionÂ\x89Ã\x9b_']

# %%
list(df_raw['text'].sample(5))
# Out:
# ['Japan Aogashima Volcano. By Unknown - Check It Out! http://t.co/OegFQBIqIq\n #Aogashima #Japan #photography #Volcano',
#  'Chemical spill at a house in Hammondville. Emergency services attending. #BreakingNews #7News http://t.co/bQ94MjYgfe',
#  "Let's destroy Twitter with @fouseyTUBE @zaynmalik come on BrBrS lets do it in morning with fousey",
#  'A sinkhole grows in Brooklyn: six-meter crater swallows street http://t.co/LTLh53aRN4',
#  'BREAKING: Terror Attack On\nPolice Post #Udhampur']

# %% [markdown]
# How would you view 5 random samples? Remember what you did earlier with `.head(5)`? Try it above!

# %% [markdown]
# Since each row is data collected from a single tweet, how can we find the total number of tweets in the dataset?
# hint: use `len(dataframe)` to count the number of rows in a dataframe

# %%
# your code here
len(df_raw)
# Out:
# 10876

# %% [markdown]
# ### Focusing on the text data
#
# Excellent! Let us now move into just the text. Since we do not need the rest of the columns, let us create a new dataframe that consists of just the text. It is a good practice to put 'df' in front of the names of dataframes to help you remember that you are working with an object of type:dataframe. using `.copy()` makes sure that you do not modify the original, raw, dataset.

# %%
df_text = df_raw['text'].copy()

# %% [markdown]
# Check if the dataframe you have just created contains what you expect. Print out the first few lines of your new dataframe and check that they only contain the tweets in the 'text' column.

# %%
# your code here
df_text.head()
# Out:
# 0                   Just happened a terrible car crash
# 1    Our Deeds are the Reason of this #earthquake M...
# 2    Heard about #earthquake is different cities, s...
# 3    there is a forest fire at spot pond, geese are...
# 4               Forest fire near La Ronge Sask. Canada
# Name: text, dtype: object

# %% [markdown]
# ## 2.2 NLP data preprocessing

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# Profanity filtering is a very important step of data pre-processing. As the AI model cannot differentiate between a good word and a bad word,it can predict outputs with the same bad words very naively.Therefore it becomes imperative for us to only train the model with clean data.

# %%
## removing unsavoury words
## We are trying to check the number of times the word 'stupid' occurs in our dataset
frequecy_of_word=0
for i in range(len(df_raw)):
    x=df_raw["text"][i]  
    if "stupid" in x:
        frequecy_of_word+=1   # frequency of word= frequency of word+1
    else:
        continue

print("The frequency of the word stupid is :",frequecy_of_word)
# Out:
# The frequency of the word stupid is : 1

# %% [markdown]
# Therefore we remove the word "stupid" by replacing it with blank spaces, which can be seen in the next cell.

# %%
for i in range(len(df_raw)):
    x=df_raw['text'][i]
    x=x.replace("stupid","") # replacing the word stupid with a blank space
    df_raw['text'][i]=x
    

    
    
frequecy_of_word=0
for i in range(len(df_raw)):
    x=df_raw["text"][i]
    if "stupid" in x:
        frequecy_of_word+=1
    else:
        continue

print("The frequency of the word stupid is :",frequecy_of_word)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8668\619871936.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_raw['text'][i]=x
# The frequency of the word stupid is : 0

# %% [markdown]
# <b>This is how we take care of explicit language in the raw data.<b>

# %% [markdown]
# ### Tokenization
#
# The first step in the NLP task is to tokenize your tweets. Do you remember what tokenization does? let us see an example! We will use a single tweet to demonstrate what each process does. The tokenization is done by calling nltk.tokenize.word_token(your data here). See if you can tell what the function did by printing the text before and after tokenization.

# %%
sample_tweet = df_text.iloc[100]
print('Before tokenization:', sample_tweet)
# Out:
# Before tokenization: http://t.co/GKYe6gjTk5 Had a #personalinjury accident this summer? Read our advice &amp; see how a #solicitor can help #OtleyHour

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
tokenized_tweet = nltk.tokenize.word_tokenize(sample_tweet)
print('After tokenization:', tokenized_tweet)
# Out:
# After tokenization: ['http', ':', '//t.co/GKYe6gjTk5', 'Had', 'a', '#', 'personalinjury', 'accident', 'this', 'summer', '?', 'Read', 'our', 'advice', '&', 'amp', ';', 'see', 'how', 'a', '#', 'solicitor', 'can', 'help', '#', 'OtleyHour']

# %% [markdown]
# Can you tell what the tokenization step did? We can easily tell what individual words are when given a sentence but computers can't. We need to break the sentence up into words for the computer.
#
# Another benefit of breaking up the sentence is that we can now measure the number of unique words in the corpus (our collection of texts). This is known as the vocabulary of the corpus.
#
# To do this we use a technique called [list comprehension](https://www.pythonforbeginners.com/basics/list-comprehensions-in-python). The objective is to put all tokens in all tweets into a single list, then finding the number of unique values in that list of tokens.

# %%
tokenized_raw = [nltk.tokenize.word_tokenize(x) for x in list(df_text)] # Creates a list of tweets, with each tweet being a list of tokens #x is a counter

len(set([y for x in tokenized_raw for y in x])) # Flattens the lists into a single list, then counts the number of unique tokens
# Out:
# 34878

# %% [markdown]
# We now know that there are 35335 unique tokens in the tweet dataset. That seems like a lot of words! One of the goals of text normalization is to reduce the number of words in the vocabulary by eliminating redundant words without sacrificing the meaning of the text.

# %% [markdown]
# ### Stemming and Lemming
#
# Now, let us look at what stemming and lemming does to the same sample tweet. We use the Porter Stemmer provided by `nltk.stem.PorterStemmer()`, as well as the Word Net lemmatizer by calling `nltk.stem.WordNetLemmatizer()`. Look at the printed outputs and compare them to the tokenized text above to spot the difference of each tool.

# %%
porter = nltk.stem.PorterStemmer()
wnl = nltk.stem.WordNetLemmatizer()

stemmed = [porter.stem(word) for word in tokenized_tweet]
print(stemmed)
#lemmed = [wnl.lemmatize(word) for word in tokenized_tweet]
#print(lemmed)
# Out:
# ['http', ':', '//t.co/gkye6gjtk5', 'had', 'a', '#', 'personalinjuri', 'accid', 'thi', 'summer', '?', 'read', 'our', 'advic', '&', 'amp', ';', 'see', 'how', 'a', '#', 'solicitor', 'can', 'help', '#', 'otleyhour']

# %% [markdown]
# Can you tell what they do? [The difference](https://blog.bitext.com/what-is-the-difference-between-stemming-and-lemmatization/) is subtle.
#
# A stemmer works by shortening words so that words with the same meaning but different forms will end up with the same token. For example, the token 'accident' was stemmed to 'accid'. Other similar words such as 'accidentally', 'accidental', and 'accidents' will all be stemmed to 'accid'. This helps to group words with similar meanings together.
#
# A lemmatizer is slightly different. It searches for words with the same meaning and replaces them with the root word. So words with the same meaning but quite different spellings will be understood by the computer to be a single word. The disadvantage of a lemmer is that it can take a long time to run.

# %% [markdown]
# ### Removing stop-words
# Next, we normalize the text by removing stop-words. Do you remember what stopwords are? nltk provides us with a list of stop words, let's see what they contain.

# %%
stop = nltk.corpus.stopwords.words('english')
# Add a few more stop words we would like to remove here
stop.append('@')
stop.append('#')
stop.append('http')
stop.append(':')
stop
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  '@',
#  '#',
#  'http',
#  ':']

# %% [markdown]
# Now that we know what each piece of code does, we can build a function that takes in the dataframe, and returns the tokenized tweets.

# %%
def process_tweet(tweet):
    tokenized_tweet = nltk.tokenize.word_tokenize(tweet)
    stemmed = [porter.stem(word) for word in tokenized_tweet]
    processed = [w.lower() for w in stemmed if w not in stop]
    return processed

def tokenizerf(df):
    tweets = []
    for _, tweet in df.iterrows():
        tweets.append(process_tweet(tweet['text']))
    return tweets

tweets = tokenizerf(df_raw)

# %% [markdown]
# Pay close attention to the processed tweets. Do you notice that there are many words that are cut (e.g. terribl instead of terrible)? Do you remember why this is done?

# %%
tweets
# Out:
# [['happen', 'terribl', 'car', 'crash'],
#  ['deed', 'reason', 'thi', 'earthquak', 'may', 'allah', 'forgiv', 'us'],
#  ['heard', 'earthquak', 'differ', 'citi', ',', 'stay', 'safe', 'everyon', '.'],
#  ['forest',
#   'fire',
#   'spot',
#   'pond',
#   ',',
#   'gees',
#   'flee',
#   'across',
#   'street',
#   ',',
#   'save'],
#  ['forest', 'fire', 'near', 'la', 'rong', 'sask', '.', 'canada'],
#  ['resid',
#   'ask',
#   "'shelter",
#   'place',
#   "'",
#   'notifi',
#   'offic',
#   '.',
#   'evacu',
#   'shelter',
#   'place',
#   'order',
#   'expect'],
#  ['13,000', 'peopl', 'receiv', 'wildfir', 'evacu', 'order', 'california'],
#  ['got',
#   'sent',
#   'thi',
#   'photo',
#   'rubi',
#   'alaska',
#   'smoke',
#   'wildfir',
#   'pour',
#   'school'],
#  ['rockyfir',
#   'updat',
#   '=',
#   '>',
#   'california',
#   'hwi',
#   '.',
#   '20',
#   'close',
#   'direct',
#   'due',
#   'lake',
#   'counti',
#   'fire',
#   '-',
#   'cafir',
#   'wildfir'],
#  ['apocalyps', 'light', '.', 'spokan', 'wildfir'],
#  ['flood',
#   'disast',
#   'heavi',
#   'rain',
#   'caus',
#   'flash',
#   'flood',
#   'street',
#   'manit',
#   ',',
#   'colorado',
#   'spring',
#   'area'],
#  ['typhoon', 'soudelor', 'kill', '28', 'china', 'taiwan'],
#  ["'re", 'shake', '...', "'s", 'earthquak'],
#  ["'m", 'top', 'hill', 'see', 'fire', 'wood', '...'],
#  ["'s", 'emerg', 'evacu', 'happen', 'build', 'across', 'street'],
#  ["'m", 'afraid', 'tornado', 'come', 'area', '...'],
#  ['three', 'peopl', 'die', 'heat', 'wave', 'far'],
#  ['haha',
#   'south',
#   'tampa',
#   'get',
#   'flood',
#   'hah-',
#   'wait',
#   'second',
#   'live',
#   'south',
#   'tampa',
#   'gon',
#   'na',
#   'gon',
#   'na',
#   '*',
#   '*',
#   '*',
#   '*',
#   'flood'],
#  ['rain',
#   'flood',
#   'florida',
#   'tampabay',
#   'tampa',
#   '18',
#   '19',
#   'day',
#   '.',
#   "'ve",
#   'lost',
#   'count'],
#  ['flood', 'bago', 'myanmar', 'arriv', 'bago'],
#  ['damag', 'school', 'bu', '80', 'multi', 'car', 'crash', 'break'],
#  ["'d",
#   'probabl',
#   'still',
#   'show',
#   'life',
#   'arsen',
#   'yesterday',
#   ',',
#   'eh',
#   '?',
#   'eh',
#   '?'],
#  ['hey', '!', '?'],
#  ["'s", 'man', '?'],
#  ['love', 'fruit'],
#  ['summer', 'love'],
#  ['car', 'fast'],
#  ['nice', 'hat', '?'],
#  ['goooooooaaaaaal', '!', '!', '!', '!', '!', '!'],
#  ['*', '*', '*', '*', '!'],
#  ["n't", 'like', 'cold', '!'],
#  ['thi', 'ridicul', '....'],
#  ['london', 'cool', ';', ')'],
#  ['love', 'ski'],
#  ['wonder', 'day', '!'],
#  ['nooooooooo', '!', "n't", '!'],
#  ['looooool'],
#  ['way', '...', 'ca', "n't", 'eat', '*', '*', '*', '*'],
#  ['wa', 'nyc', 'last', 'week', '!'],
#  ['love', 'girlfriend'],
#  ['cooool', ')'],
#  ['like', 'pasta', '?'],
#  ["n't", 'tell', '!'],
#  ['?', '!'],
#  ['end', '!'],
#  ['awesom', '!'],
#  ['birmingham',
#   'wholesal',
#   'market',
#   'ablaz',
#   'bbc',
#   'new',
#   '-',
#   'fire',
#   'break',
#   'birmingham',
#   "'s",
#   'wholesal',
#   'market',
#   '//t.co/irwqcezweu'],
#  ['sunkxssedharri', 'wear', 'short', 'race', 'ablaz', '?'],
#  ['bbcmtd', 'wholesal', 'market', 'ablaz', '//t.co/lhyxeohy6c'],
#  ['alway', 'tri', 'bring', 'heavi', '.', 'metal', 'rt', '//t.co/yao1e0xngw'],
#  ['africanbaz',
#   'break',
#   'news',
#   'nigeria',
#   'flag',
#   'set',
#   'ablaz',
#   'aba',
#   '.',
#   '//t.co/2nndbgwyei'],
#  ['previouslyondoyintv',
#   '*',
#   '*',
#   '*',
#   '*',
#   'makinwaâ\x89ã\x9bâª',
#   'marriag',
#   'crisi',
#   'set',
#   'nigerian',
#   'twitter',
#   'ablaz',
#   '...',
#   '//t.co/cmghxba2xi'],
#  ['cri', '!', 'set', 'ablaz'],
#  ['plu',
#   'side',
#   'look',
#   'ski',
#   'last',
#   'night',
#   'wa',
#   'ablaz',
#   '//t.co/qqsmshaj3n'],
#  ['phdsquar',
#   'mufc',
#   "'ve",
#   'built',
#   'much',
#   'hype',
#   'around',
#   'new',
#   'acquisit',
#   'doubt',
#   'set',
#   'epl',
#   'ablaz',
#   'thi',
#   'season',
#   '.'],
#  ['inec', 'offic', 'abia', 'set', 'ablaz', '-', '//t.co/3imaomknna'],
#  ['barbado',
#   'bridgetown',
#   'jamaica',
#   'â\x89ã\x9bã\x92',
#   'two',
#   'car',
#   'set',
#   'ablaz',
#   'santa',
#   'cruz',
#   'â\x89ã\x9bã\x93',
#   'head',
#   'st',
#   'elizabeth',
#   'polic',
#   'superintend',
#   '...',
#   '//t.co/wdueaj8q4j'],
#  ['ablaz', 'lord'],
#  ['check',
#   '//t.co/roi2nsmejj',
#   '//t.co/3tj8zjin21',
#   '//t.co/yduixefip',
#   '//t.co/lxtjc87kl',
#   'nsfw'],
#  ['check',
#   '//t.co/roi2nsmejj',
#   '//t.co/3tj8zjin21',
#   '//t.co/yduixefip',
#   '//t.co/lxtjc87kl',
#   'nsfw'],
#  ['psa',
#   'iâ\x89ã\x9bâªm',
#   'split',
#   'person',
#   '.',
#   '?',
#   '?',
#   'techi',
#   'follow',
#   'ablaze_co',
#   '?',
#   '?',
#   'burner',
#   'follow',
#   'ablaz'],
#  ['outsid', "'re", 'ablaz', 'aliv', "'re", 'dead', 'insid'],
#  ['awesom',
#   'time',
#   'visit',
#   'cfc',
#   'head',
#   'offic',
#   'ancop',
#   'site',
#   'ablaz',
#   '.',
#   'thank',
#   'tita',
#   'vida',
#   'take',
#   'care',
#   'us',
#   '?',
#   '?'],
#  ['soooo', 'pump', 'ablaz', '?', '?', '?', '?', 'southridgelif'],
#  ['want',
#   'set',
#   'chicago',
#   'ablaz',
#   'preach',
#   '...',
#   'hotel',
#   '!',
#   '//t.co/o9qknbfofx'],
#  ['gain',
#   '3',
#   'follow',
#   'last',
#   'week',
#   '.',
#   '?',
#   'know',
#   'stat',
#   'grow',
#   '//t.co/tiyulif5c6'],
#  ['west',
#   'wa',
#   'burn',
#   'thousand',
#   'wildfir',
#   'ablaz',
#   'california',
#   'alon',
#   '//t.co/vl5tbr3wbr'],
#  ['build', 'perfect', 'tracklist', 'life', 'leav', 'street', 'ablaz'],
#  ['check',
#   '//t.co/roi2nsmejj',
#   '//t.co/3tj8zjin21',
#   '//t.co/yduixefip',
#   '//t.co/lxtjc87kl',
#   'nsfw'],
#  ['bewar', 'world', 'ablaz', 'sierra', 'leon', '&', 'amp', ';', 'guap', '.'],
#  ['burn',
#   'man',
#   'ablaz',
#   '!',
#   'turban',
#   'diva',
#   '//t.co/hodwosamw',
#   'via',
#   'etsi'],
#  ['first',
#   'night',
#   'retain',
#   '.',
#   "'s",
#   'quit',
#   'weird',
#   '.',
#   'better',
#   'get',
#   'use',
#   ';',
#   'wear',
#   'everi',
#   'singl',
#   'night',
#   'next',
#   'year',
#   'least',
#   '.'],
#  ['diss',
#   'song',
#   '.',
#   'peopl',
#   'take',
#   '1',
#   'thing',
#   'run',
#   '.',
#   'smh',
#   "'s",
#   'eye',
#   'open',
#   'though',
#   '.',
#   '2',
#   'set',
#   'game',
#   'ablaz',
#   'cyhitheprync'],
#  ['deputi',
#   'man',
#   'shot',
#   'befor',
#   'brighton',
#   'home',
#   'set',
#   'ablaz',
#   '//t.co/gwnrhmso8k'],
#  ['man',
#   'wife',
#   'get',
#   'six',
#   'year',
#   'jail',
#   'set',
#   'ablaz',
#   'niec',
#   '//t.co/ev1ahoucza'],
#  ['*',
#   '*',
#   '*',
#   '*',
#   'victim',
#   'die',
#   'set',
#   'ablaz',
#   '16-year-old',
#   'girl',
#   'die',
#   'burn',
#   'injuri',
#   'set',
#   'ablazeâ\x89ã\x9b_',
#   '//t.co/uk8hnrboob'],
#  ['santa',
#   'cruz',
#   'â\x89ã\x9bã\x93',
#   'head',
#   'st',
#   'elizabeth',
#   'polic',
#   'superintend',
#   'lanford',
#   'salmon',
#   'ha',
#   'r',
#   '...',
#   '-',
#   '//t.co/vplr5hka2u',
#   '//t.co/sxhw2tnnlf'],
#  ['polic',
#   'arsonist',
#   'deliber',
#   'set',
#   'black',
#   'church',
#   'north',
#   'carolinaã¥ã\x8aablaz',
#   '//t.co/pcxarbh9an'],
#  ['noch',
#   'el-bestia',
#   "'",
#   'alexis_sanchez',
#   'happi',
#   'see',
#   'teammat',
#   'train',
#   'hard',
#   '?',
#   '?',
#   'goodnight',
#   'gunners.',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '//t.co/uc4j4jhvgr',
#   "'"],
#  ['kurd',
#   'trampl',
#   'turkmen',
#   'flag',
#   'later',
#   'set',
#   'ablaz',
#   'vandal',
#   'offic',
#   'turkmen',
#   'front',
#   'diyala',
#   '//t.co/4izfdyc3cg'],
#  ['truck',
#   'ablaz',
#   'r21',
#   '.',
#   'voortrekk',
#   'ave.',
#   'outsid',
#   'tambo',
#   'intl',
#   '.',
#   'cargo',
#   'section',
#   '.',
#   '//t.co/8kscqkfkkf'],
#  ['set',
#   'heart',
#   'ablaz',
#   'everi',
#   'citi',
#   'wa',
#   'gift',
#   'everi',
#   'skylin',
#   'wa',
#   'like',
#   'kiss',
#   'upon',
#   'lip',
#   'â\x89ã\x9b_',
#   '//t.co/cyompz1a0z'],
#  ['sky',
#   'wa',
#   'ablaz',
#   'tonight',
#   'lo',
#   'angel',
#   '.',
#   "'m",
#   'expect',
#   'ig',
#   'fb',
#   'fill',
#   'sunset',
#   'shot',
#   'know',
#   'peep',
#   '!',
#   '!'],
#  ['west',
#   'wa',
#   'burn',
#   'thousand',
#   'wildfir',
#   'ablaz',
#   'california',
#   'alon',
#   '//t.co/icsjgz9te1',
#   'climat',
#   'energi',
#   '//t.co/9fxmn0l0bd'],
#  ['set', 'ablaz', '//t.co/6vme7p5xhc'],
#  ['revel',
#   'wmv',
#   'video',
#   'mean',
#   'mac',
#   'farewel',
#   'ablaz',
#   'wmv',
#   'en',
#   'rout',
#   'dvd',
#   'gtxrwm'],
#  ['progress',
#   'greet',
#   '!',
#   'month',
#   'student',
#   'would',
#   'set',
#   'pen',
#   'ablaz',
#   'torch',
#   'public',
#   "'",
#   '...',
#   '//t.co/9fxpixqujt'],
#  ['ctvtoronto',
#   'bin',
#   'front',
#   'field',
#   'hous',
#   'wer',
#   'set',
#   'ablaz',
#   'day',
#   'flame',
#   'went',
#   'rite',
#   'hydro',
#   'pole',
#   'wonder',
#   'wa'],
#  ['nowplay',
#   'alfon',
#   '-',
#   'ablaz',
#   '2015',
#   'pul',
#   'radio',
#   'pulsradio',
#   '//t.co/aa5bjgwfdv'],
#  ['rene',
#   'ablaz',
#   '&',
#   'amp',
#   ';',
#   'jacinta',
#   '-',
#   'secret',
#   '2k13',
#   '(',
#   'fallen',
#   'ski',
#   'edit',
#   ')',
#   '-',
#   'mar',
#   '30',
#   '2013',
#   '//t.co/7mlmsuzv1z'],
#  ["'burn",
#   'rahm',
#   "'",
#   'let',
#   "'s",
#   'hope',
#   'citi',
#   'hall',
#   'build',
#   'giant',
#   'wooden',
#   'mayor',
#   'effigi',
#   '100',
#   'feet',
#   'tall',
#   '&',
#   'amp',
#   ';',
#   'set',
#   'ablaz',
#   '.',
#   '//t.co/kfo2mksn6i',
#   'john_k'],
#  ['navista7',
#   'steve',
#   'fire',
#   'someth',
#   'els',
#   '!',
#   'california',
#   'tinderbox',
#   '-',
#   'thi',
#   'clown',
#   'wa',
#   'set',
#   "'hood",
#   'ablaz',
#   'news24680'],
#  ['nowplay',
#   'rene',
#   'ablaz',
#   '&',
#   'amp',
#   ';',
#   'ian',
#   'buff',
#   '-',
#   'magnitud',
#   '//t.co/av2jsjfftc',
#   'edm'],
#  ['nxwestmidland',
#   'huge',
#   'fire',
#   'wholesal',
#   'market',
#   'ablaz',
#   '//t.co/rwzbfvnxer'],
#  ['philippaeilhart',
#   'dhublath',
#   'hurt',
#   'eye',
#   'ablaz',
#   'insult',
#   'anger',
#   '.'],
#  ['ablaz',
#   'time',
#   'doe',
#   'talk',
#   'go',
#   '?',
#   "n't",
#   'know',
#   'make',
#   'due',
#   'work',
#   '.'],
#  ["'",
#   'ca',
#   "n't",
#   'kid',
#   'cuz',
#   'got',
#   'bicycl',
#   'accid',
#   '&',
#   'amp',
#   ';',
#   'split',
#   'testicl',
#   '.',
#   "'s",
#   'imposs',
#   'kid',
#   "'",
#   'michael',
#   'father'],
#  ['accid',
#   'i-24',
#   'w',
#   'nashvilletraff',
#   '.',
#   'traffic',
#   'move',
#   '8m',
#   'slower',
#   'usual',
#   '.',
#   '//t.co/0ghk693egj'],
#  ['accid',
#   'center',
#   'lane',
#   'block',
#   'santaclara',
#   'us-101',
#   'nb',
#   'befor',
#   'great',
#   'america',
#   'pkwi',
#   'bayarea',
#   'traffic',
#   '//t.co/pmlohzurwr'],
#  ['accid',
#   'clear',
#   'paturnpik',
#   'patp',
#   'eb',
#   'pa-18',
#   'cranberri',
#   'slow',
#   'back',
#   'traffic',
#   '//t.co/sl0oqn0vyr'],
#  ['//t.co/gkye6gjtk5',
#   'personalinjuri',
#   'accid',
#   'thi',
#   'summer',
#   '?',
#   'read',
#   'advic',
#   '&',
#   'amp',
#   ';',
#   'see',
#   'solicitor',
#   'help',
#   'otleyhour'],
#  ['got',
#   'love',
#   'burn',
#   'self',
#   '*',
#   '*',
#   '*',
#   '*',
#   'curl',
#   'wand',
#   '...',
#   'swear',
#   'someon',
#   'need',
#   'take',
#   'away',
#   'cuas',
#   "'m",
#   'accid',
#   'prone',
#   '.'],
#  ['stloui',
#   'caraccidentlawy',
#   'speed',
#   'among',
#   'top',
#   'caus',
#   'teen',
#   'accid',
#   '//t.co/k4zomof319',
#   '//t.co/s2kxvm0cba',
#   'car',
#   'accid',
#   'teeâ\x89ã\x9b_'],
#  ['hate', 'badg', '*', '*', '*', '*', 'accid'],
#  ['report',
#   'motor',
#   'vehicl',
#   'accid',
#   'curri',
#   'herman',
#   'rd',
#   'near',
#   'stephenson',
#   'involv',
#   'overturn',
#   'vehicl',
#   '.',
#   'pleas',
#   'use',
#   '...',
#   '//t.co/ybjezkurw1'],
#  ['bigrigradio', 'live', 'accid', 'awar'],
#  ['3',
#   'car',
#   'record',
#   'zeroedgeã¥â¨',
#   'dual-len',
#   'car',
#   'camera',
#   'vehicl',
#   'traffic/driv',
#   'history/accid',
#   'camcord',
#   'larg',
#   '...',
#   '//t.co/kkfasjv6cj'],
#  ['i-77',
#   'mile',
#   'marker',
#   '31',
#   'south',
#   'mooresvil',
#   'iredel',
#   'vehicl',
#   'accid',
#   'ramp',
#   'close',
#   '8/6',
#   '1:18',
#   'pm'],
#  ['coincid',
#   'curs',
#   '?',
#   'still',
#   'unresolv',
#   'secret',
#   'past',
#   '//t.co/7vg8df9pl',
#   'accid'],
#  ['rt',
#   'sleepjunki',
#   'sleep',
#   'pill',
#   'doubl',
#   'risk',
#   'car',
#   'accid',
#   '//t.co/7s9nm1fict'],
#  ["'bi", 'accid', "'", 'knew', 'wa', 'gon', 'happen', '//t.co/ysxun5vceh'],
#  ['traffic_south',
#   'roadpol_east',
#   'accid',
#   'a27',
#   'near',
#   'lew',
#   'kingston',
#   'roundabout',
#   'rather',
#   'a283'],
#  ['traffic',
#   'accid',
#   'n',
#   'cabrillo',
#   'hwy/magellan',
#   'av',
#   'mir',
#   '(',
#   '08/06/15',
#   '11:03:58',
#   ')'],
#  ['i-77',
#   'mile',
#   'marker',
#   '31',
#   '40',
#   'south',
#   'mooresvil',
#   'iredel',
#   'vehicl',
#   'accid',
#   'congest',
#   '8/6',
#   '1:18',
#   'pm'],
#  ['pastor',
#   'wa',
#   'scene',
#   'accid',
#   '......',
#   'wa',
#   'owner',
#   'rang',
#   'rover',
#   '?'],
#  ['sakuma_en',
#   'pretend',
#   'feel',
#   'certain',
#   'way',
#   'feel',
#   'becom',
#   'genuin',
#   'accid',
#   '.',
#   '-hei',
#   '(',
#   'darker',
#   'black',
#   ')',
#   'manga',
#   'anim'],
#  ['legal',
#   'medic',
#   'referr',
#   'servic',
#   '1800_injur',
#   'call',
#   'us',
#   '1-800-465-87332',
#   'accid',
#   'slipandfal',
#   'dogbit'],
#  ['mom',
#   "'we",
#   "n't",
#   'get',
#   'home',
#   'fast',
#   'wish',
#   "'",
#   "'whi",
#   '?',
#   "'",
#   'mom',
#   "'there",
#   'wa',
#   'accid',
#   'truck',
#   'spilt',
#   'mayonnais',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?'],
#  ['wa',
#   'horribl',
#   'car',
#   'accid',
#   'thi',
#   'past',
#   'sunday',
#   '.',
#   "'m",
#   'final',
#   'abl',
#   'get',
#   'around',
#   '.',
#   'thank',
#   '*',
#   '*',
#   '*',
#   '*',
#   '?',
#   '?'],
#  ['wait',
#   'see',
#   '*',
#   '*',
#   '*',
#   '*',
#   'donni',
#   'tell',
#   'wa',
#   'anoth',
#   'accid',
#   '?',
#   '?'],
#  ['truckcrash',
#   'overturn',
#   'fortworth',
#   'interst',
#   '//t.co/rs22lj4qfp',
#   'click',
#   "'ve",
#   'crash',
#   '&',
#   'gt',
#   ';',
#   '//t.co/ld0uniyw4k'],
#  ['accid',
#   'ashvil',
#   'us',
#   '23',
#   'sb',
#   'befor',
#   'sr',
#   '752',
#   'traffic',
#   '//t.co/hylmo0wgfi'],
#  ["'s",
#   'construct',
#   'guy',
#   'work',
#   'disney',
#   'store',
#   'ha',
#   'huge',
#   'gaug',
#   'hi',
#   'ear',
#   '?',
#   '?',
#   '...',
#   'bloodi',
#   'accid',
#   'wait',
#   'happen'],
#  ['robynjilllian',
#   'wlsdomteeth',
#   'feel',
#   'like',
#   "'m",
#   'go',
#   'accid',
#   '.',
#   'teesha',
#   'gon',
#   'na',
#   'come',
#   '?',
#   '?'],
#  ['m42',
#   'northbound',
#   'junction',
#   'j3',
#   'j3a',
#   'current',
#   'delay',
#   '10',
#   'min',
#   'due',
#   'accid',
#   'c',
#   '...',
#   '//t.co/lwi3prba31'],
#  ['daveoshri',
#   'soembi',
#   'say',
#   'met',
#   'accid',
#   'thi',
#   'week-',
#   'would',
#   'super',
#   'jelli',
#   'dave',
#   '?',
#   'p'],
#  ['carolina',
#   'accid',
#   'motorcyclist',
#   'die',
#   'i-540',
#   'crash',
#   'car',
#   'cross',
#   'median',
#   'motorcycl',
#   'rider',
#   'travel',
#   '...',
#   '//t.co/p18lzrlmy6'],
#  ['accid',
#   '-',
#   'hit',
#   'run',
#   '-',
#   'cold',
#   '500',
#   'block',
#   'se',
#   'vista',
#   'ter',
#   'gresham',
#   '[',
#   'gresham',
#   'polic',
#   'pg15000044357',
#   ']',
#   '10:35',
#   'pdx911'],
#  ['fyi',
#   'cad',
#   'fyi',
#   ';',
#   'accid',
#   'properti',
#   'damag',
#   ';',
#   'nh',
#   ';',
#   '999',
#   'piner',
#   'rd/horndal',
#   'dr'],
#  ['rt',
#   'naayf',
#   'first',
#   'accid',
#   'year',
#   '.',
#   'turn',
#   'onto',
#   'chandane',
#   'magu',
#   'near',
#   'mma',
#   '.',
#   'taxi',
#   'ram',
#   'wa',
#   'halfway',
#   'turn',
#   '.',
#   'everyon',
#   'confâ\x89ã\x9b_'],
#  ['accid',
#   'left',
#   'lane',
#   'block',
#   'manchest',
#   'rt',
#   '293',
#   'nb',
#   'befor',
#   'eddi',
#   'rd',
#   'stop',
#   'go',
#   'traffic',
#   'back',
#   'nh-3a',
#   'delay',
#   '4',
#   'min',
#   'traffic'],
#  [';', 'accid', 'properti', 'damag', ';', 'piner', 'rd/horndal', 'dr'],
#  ['?', '?', '?', '?', 'wa', 'accid', '//t.co/oia5fxi4gm'],
#  ['fyi',
#   'cad',
#   'fyi',
#   ';',
#   'accid',
#   'properti',
#   'damag',
#   ';',
#   'wpd',
#   ';',
#   '1600',
#   '17th',
#   'st'],
#  ['8/6/2015',
#   '2:09',
#   'pm',
#   'traffic',
#   'accid',
#   'injuri',
#   '2781',
#   'willi',
#   'foreman',
#   'rd',
#   '//t.co/vckit6edev'],
#  ['aashiqui',
#   'actress',
#   'anu',
#   'aggarw',
#   'near-fat',
#   'accid',
#   '//t.co/6otfp31lqw'],
#  ['suffield', 'alberta', 'accid', '//t.co/bptmlf4p10'],
#  ['9',
#   'mile',
#   'backup',
#   'i-77',
#   'south',
#   '...',
#   'accid',
#   'block',
#   'right',
#   '2',
#   'lane',
#   'exit',
#   '31',
#   'langtre',
#   'rd',
#   '...',
#   'consid',
#   'nc',
#   '115',
#   'nc',
#   '150',
#   'nc',
#   '16',
#   'altern'],
#  ['ha',
#   'accid',
#   'chang',
#   'life',
#   '?',
#   'help',
#   'determin',
#   'option',
#   'financi',
#   'support',
#   'life',
#   'care',
#   'plan',
#   'on-go',
#   'treatment',
#   '.'],
#  ['break',
#   'wa',
#   'deadli',
#   'motorcycl',
#   'car',
#   'accid',
#   'happen',
#   'hagerstown',
#   'today',
#   '.',
#   "'ll",
#   'detail',
#   '5',
#   'your4stat',
#   '.',
#   'whag'],
#  ['calum5so', 'thi', 'happen', 'accid', 'like', '//t.co/qhmxuljsx9'],
#  ['flowri', 'marinad', 'wa', 'accid', '?'],
#  ['pleas',
#   'donat',
#   'spread',
#   'word',
#   '!',
#   'train',
#   'accid',
#   'left',
#   'pole-vault',
#   'kira',
#   'grã\x8c_nberg',
#   'parapleg',
#   '//t.co/6mpnycl8pk'],
#  ['onli',
#   'car',
#   'even',
#   'week',
#   'got',
#   '*',
#   '*',
#   '*',
#   '*',
#   'car',
#   'accid',
#   '..',
#   'mf',
#   'ca',
#   "n't",
#   '*',
#   '*',
#   '*',
#   '*',
#   'drive',
#   '.'],
#  ['.',
#   'norwaymfa',
#   'bahrain',
#   'polic',
#   'previous',
#   'die',
#   'road',
#   'accid',
#   'kill',
#   'explos',
#   '//t.co/gfjfgtodad'],
#  ['still',
#   'heard',
#   'church',
#   'leader',
#   'kenya',
#   'come',
#   'forward',
#   'comment',
#   'accid',
#   'issu',
#   'disciplinari',
#   'measur',
#   'arrestpastornganga'],
#  ['aftershock_delo', 'scuf', 'ps', 'live', 'game', '...', 'cya'],
#  ['pleas',
#   'like',
#   'share',
#   'new',
#   'page',
#   'indoor',
#   'trampolin',
#   'park',
#   'aftershock',
#   'open',
#   'thi',
#   'fall',
#   '!',
#   '!',
#   '//t.co/ugxhherrx'],
#  ['bxckylynch',
#   'foi',
#   'roh',
#   'aftershock',
#   'la',
#   'vega',
#   'procura',
#   'pirat',
#   'bay',
#   'que',
#   'tem'],
#  ["'the",
#   'man',
#   'drive',
#   'onc',
#   'effort',
#   'get',
#   'pain',
#   'man',
#   'win',
#   '.',
#   "'",
#   'roger',
#   'bannist'],
#  ['schoolboy',
#   'â\x89ã\x9bã\x92',
#   'aftershock',
#   '(',
#   'origin',
#   'mix',
#   ')',
#   'excis',
#   '&',
#   'amp',
#   ';',
#   'skism',
#   'â\x89ã\x9bã\x92',
#   'sexism',
#   '(',
#   'far',
#   'loud',
#   'remix',
#   ')',
#   'firebeatz',
#   'schella',
#   'â\x89ã\x9bã\x92',
#   'dear',
#   'new',
#   '...',
#   '//t.co/jqlzua6yzq'],
#  ['320',
#   '[',
#   'ir',
#   ']',
#   'icemoon',
#   '[',
#   'aftershock',
#   ']',
#   '|',
#   '//t.co/ynxnvvkcda',
#   '|',
#   'djicemoon',
#   '|',
#   'dubstep',
#   'trapmus',
#   'dnb',
#   'edm',
#   'danc',
#   'icesâ\x89ã\x9b_',
#   '//t.co/weqpesenku'],
#  ['320',
#   '[',
#   'ir',
#   ']',
#   'icemoon',
#   '[',
#   'aftershock',
#   ']',
#   '|',
#   '//t.co/thyzomvwu0',
#   '|',
#   'djicemoon',
#   '|',
#   'dubstep',
#   'trapmus',
#   'dnb',
#   'edm',
#   'danc',
#   'icesâ\x89ã\x9b_',
#   '//t.co/83joo0xk29'],
#  ["'there",
#   'victori',
#   'bargain',
#   'basement',
#   'price',
#   '.',
#   "'",
#   'dwight',
#   'david',
#   'eisenhow'],
#  ["'when",
#   'aftershock',
#   'happen',
#   '(',
#   'nepal',
#   ')',
#   'last',
#   'int',
#   "'",
#   'l',
#   'team',
#   'still',
#   ';',
#   'way',
#   '1st',
#   'respond',
#   '.',
#   "'",
#   'chief',
#   'collin',
#   'laco_fd'],
#  ['320',
#   '[',
#   'ir',
#   ']',
#   'icemoon',
#   '[',
#   'aftershock',
#   ']',
#   '|',
#   '//t.co/grpef7yawg',
#   '|',
#   'djicemoon',
#   '|',
#   'dubstep',
#   'trapmus',
#   'dnb',
#   'edm',
#   'danc',
#   'icesâ\x89ã\x9b_',
#   '//t.co/ggmvzt58v'],
#  ['320',
#   '[',
#   'ir',
#   ']',
#   'icemoon',
#   '[',
#   'aftershock',
#   ']',
#   '|',
#   '//t.co/vam5podgyw',
#   '|',
#   'djicemoon',
#   '|',
#   'dubstep',
#   'trapmus',
#   'dnb',
#   'edm',
#   'danc',
#   'icesâ\x89ã\x9b_',
#   '//t.co/zevakjapcz'],
#  ["'nobodi", 'rememb', 'came', 'second', '.', "'", 'charl', 'schulz'],
#  ['aftershock_delo',
#   'im',
#   'speak',
#   'someon',
#   'use',
#   'scuf',
#   'xb1',
#   'peopl',
#   'end',
#   'get',
#   'ps',
#   'also',
#   '.'],
#  ["'the",
#   'harder',
#   'conflict',
#   'gloriou',
#   'triumph',
#   '.',
#   "'",
#   'thoma',
#   'pain'],
#  ['growingupspoil',
#   'go',
#   'clay',
#   'pigeon',
#   'shoot',
#   'cri',
#   'becaus',
#   "'aftershock",
#   "'"],
#  ['guess',
#   'one',
#   'actual',
#   'want',
#   'ani',
#   'free',
#   'aftershock',
#   'tc',
#   '.....'],
#  ['aftershock',
#   'wa',
#   'terrifi',
#   'best',
#   'roller',
#   'coaster',
#   "'ve",
#   'ever',
#   '.',
#   '*',
#   'disclaim',
#   '*',
#   "'ve",
#   'veri',
#   '.'],
#  ['aftershock', '//t.co/xmwodfmtui'],
#  ['320',
#   '[',
#   'ir',
#   ']',
#   'icemoon',
#   '[',
#   'aftershock',
#   ']',
#   '|',
#   '//t.co/m4jdzmgjow',
#   '|',
#   'djicemoon',
#   '|',
#   'dubstep',
#   'trapmus',
#   'dnb',
#   'edm',
#   'danc',
#   'icesâ\x89ã\x9b_',
#   '//t.co/n0uhasfkbv'],
#  ['320',
#   '[',
#   'ir',
#   ']',
#   'icemoon',
#   '[',
#   'aftershock',
#   ']',
#   '|',
#   '//t.co/vam5podgyw',
#   '|',
#   'djicemoon',
#   '|',
#   'dubstep',
#   'trapmus',
#   'dnb',
#   'edm',
#   'danc',
#   'icesâ\x89ã\x9b_',
#   '//t.co/zevakjapcz'],
#  ['stop',
#   'say',
#   "'",
#   'wish',
#   "'",
#   'start',
#   'say',
#   "'",
#   "'",
#   '.',
#   'â\x89ã\x9bã\x92',
#   'unknown'],
#  ['want',
#   'go',
#   'aftershock',
#   'octob',
#   'becaus',
#   'ha',
#   'band',
#   'listen',
#   'nxt',
#   '!',
#   'ca',
#   "n't",
#   'afford',
#   'yet',
#   'though',
#   '.',
#   'gradschoolapp'],
#  ['320',
#   '[',
#   'ir',
#   ']',
#   'icemoon',
#   '[',
#   'aftershock',
#   ']',
#   '|',
#   '//t.co/e14epzhoth',
#   '|',
#   'djicemoon',
#   '|',
#   'dubstep',
#   'trapmus',
#   'dnb',
#   'edm',
#   'danc',
#   'icesâ\x89ã\x9b_',
#   '//t.co/22a9d5do6q'],
#  ["'we",
#   'still',
#   'live',
#   'aftershock',
#   'hiroshima',
#   'peopl',
#   'still',
#   'scar',
#   'histori',
#   '.',
#   "'",
#   '-',
#   'edward',
#   'bond',
#   '//t.co/engtl5wrgp'],
#  ['kjforday', "'m", 'see', 'issu', 'aftershock', '?', '?'],
#  ['320',
#   '[',
#   'ir',
#   ']',
#   'icemoon',
#   '[',
#   'aftershock',
#   ']',
#   '|',
#   '//t.co/thyzomvwu0',
#   '|',
#   'djicemoon',
#   '|',
#   'dubstep',
#   'trapmus',
#   'dnb',
#   'edm',
#   'danc',
#   'icesâ\x89ã\x9b_',
#   '//t.co/83joo0xk29'],
#  ['320',
#   '[',
#   'ir',
#   ']',
#   'icemoon',
#   '[',
#   'aftershock',
#   ']',
#   '|',
#   '//t.co/thyzomvwu0',
#   '|',
#   'djicemoon',
#   '|',
#   'dubstep',
#   'trapmus',
#   'dnb',
#   'edm',
#   'danc',
#   'icesâ\x89ã\x9b_',
#   '//t.co/83joo0xk29'],
#  ['wisdomw',
#   'bonu',
#   '-',
#   '5',
#   'minut',
#   'daili',
#   'habit',
#   'could',
#   'realli',
#   'improv',
#   'life',
#   '.',
#   'mani',
#   'alreadi',
#   '?',
#   'lifehack',
#   '//t.co/tbm9fqb8cw'],
#  ['aftershock',
#   'protect',
#   'profit',
#   'next',
#   'global',
#   'financi',
#   'meltdown',
#   'david',
#   'wiedem',
#   '//t.co/wztz4hgmvq'],
#  ['moment',
#   'get',
#   'scari',
#   'roller',
#   'coaster',
#   'guy',
#   'behind',
#   'scream',
#   'bloodi',
#   '*',
#   '*',
#   '*',
#   '*',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   'silverwood',
#   'aftershock'],
#  ['aftershock',
#   'â\x89ã£â¢',
#   '(',
#   '2010',
#   ')',
#   'fullâ\x89ã£â¢',
#   'stream',
#   '-',
#   'youtub',
#   '//t.co/vve3usesgf'],
#  ['320',
#   '[',
#   'ir',
#   ']',
#   'icemoon',
#   '[',
#   'aftershock',
#   ']',
#   '|',
#   '//t.co/thyzomvwu0',
#   '|',
#   'djicemoon',
#   '|',
#   'dubstep',
#   'trapmus',
#   'dnb',
#   'edm',
#   'danc',
#   'icesâ\x89ã\x9b_',
#   '//t.co/83joo0xk29'],
#  ['&',
#   'gt',
#   ';',
#   '&',
#   'gt',
#   ';',
#   '$',
#   '15',
#   'aftershock',
#   'protect',
#   'profit',
#   'next',
#   'global',
#   'financi',
#   '...',
#   'book',
#   '//t.co/f6ntuc734z',
#   'esquireattir'],
#  ['aftershock', '//t.co/ecy4u623no'],
#  ['sometim',
#   'face',
#   'difficulti',
#   'becaus',
#   "'re",
#   'someth',
#   'wrong',
#   'becaus',
#   "'re",
#   'someth',
#   'right',
#   '.',
#   '-',
#   'joel',
#   'osteen'],
#  ["'there",
#   'victori',
#   'bargain',
#   'basement',
#   'price',
#   '.',
#   "'",
#   'dwight',
#   'david',
#   'eisenhow'],
#  ["'the",
#   'onli',
#   'thing',
#   'stand',
#   'dream',
#   'tri',
#   'belief',
#   'actual',
#   'possibl',
#   '.',
#   "'",
#   '-',
#   'joel',
#   'brown'],
#  ['prais',
#   '*',
#   '*',
#   '*',
#   '*',
#   'ministri',
#   'tell',
#   'like',
#   '!',
#   '!',
#   '!',
#   'wdyouth',
#   'biblestudi',
#   '//t.co/ujk0e5gbcc'],
#  ["'rememb",
#   'go',
#   'die',
#   'best',
#   'way',
#   'know',
#   'avoid',
#   'trap',
#   'think',
#   'someth',
#   'lose',
#   '.',
#   "'",
#   'â\x89ã\x9bã\x92',
#   'steve',
#   'job'],
#  ['tri', 'orang', 'aftershock', 'today', '.', 'life', 'never'],
#  ['bo2',
#   'far',
#   'best',
#   'competit',
#   'map',
#   'imo',
#   'hope',
#   'bo3',
#   'invahnwetrust'],
#  ['onfireand', 'love', 'bb'],
#  ['br',
#   'copper',
#   'cataclysm',
#   '&',
#   'amp',
#   ';',
#   'aftershock',
#   '!',
#   '!',
#   '!',
#   '//t.co/uxyzyaygti'],
#  ['jadeformkx',
#   'happi',
#   "n't",
#   'use',
#   'aftershock',
#   '.',
#   'variat',
#   'counter',
#   'play',
#   'style',
#   'hard',
#   '.'],
#  ['aftershock', '//t.co/jv8ppkhjy7'],
#  ['aftershock',
#   'back',
#   'school',
#   'kick',
#   'wa',
#   'great',
#   '.',
#   'want',
#   'thank',
#   'everyon',
#   'make',
#   'possibl',
#   '.',
#   'great',
#   'night',
#   '.'],
#  ['aftershock', '//t.co/38nhq9moef'],
#  ['peopl',
#   'say',
#   'done',
#   'interrupt',
#   '.',
#   'â\x89ã\x9bã\x92',
#   'georg',
#   'bernard',
#   'shaw'],
#  ["'the",
#   'first',
#   'man',
#   'get',
#   'oyster',
#   'second',
#   'man',
#   'get',
#   'shell',
#   '.',
#   "'",
#   'andrew',
#   'carnegi'],
#  ['anyon',
#   'need',
#   'p/u',
#   'tonight',
#   '?',
#   'play',
#   'hybrid',
#   'slayer',
#   'ps4',
#   'eu',
#   '.',
#   'hmu',
#   'cod8sandscrim',
#   'empirikgam',
#   'codawscrim',
#   '4tp_kotc',
#   '4tpfa',
#   'aftershock_org'],
#  ['expert',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accid',
#   'expert',
#   '...',
#   '//t.co/yvvpznzmxg',
#   'news'],
#  ['strict',
#   'liabil',
#   'context',
#   'airplan',
#   'accid',
#   'pilot',
#   'error',
#   'common',
#   'compon',
#   'aviat',
#   'cr',
#   '...',
#   '//t.co/6cz3bohrd4'],
#  ['crobscarla', 'lifetim', 'odd', 'die', 'airplan', 'accid', '1', '8015', '.'],
#  ['expert',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accid',
#   'expert',
#   'wedn',
#   '...',
#   '//t.co/bkpfpogysi'],
#  ['careless',
#   'lead',
#   'aviat',
#   'accid',
#   'victim',
#   'ha',
#   'right',
#   'seek',
#   'compens',
#   'damag',
#   '.',
#   '//t.co/eqag6rz1vo'],
#  ['alexalltimelow',
#   'awwww',
#   "'re",
#   'airplan',
#   'accid',
#   "'re",
#   'gon',
#   'na',
#   'die',
#   'cuti',
#   '?',
#   '?',
#   '?',
#   '?',
#   'good',
#   'job',
#   '!'],
#  ['rewind_mus',
#   'found',
#   'guy',
#   'today',
#   '(',
#   'regard',
#   'accid',
#   'airplan',
#   'lol',
#   ')',
#   '&',
#   'amp',
#   ';',
#   'becam',
#   'fan',
#   '!',
#   'send',
#   'love',
#   '&',
#   'amp',
#   ';',
#   'support',
#   'cali~',
#   '?'],
#  ['famili',
#   'member',
#   'osama',
#   'bin',
#   'laden',
#   'die',
#   'airplan',
#   'accid',
#   'iron',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   'mhmmm',
#   'gov',
#   '*',
#   '*',
#   '*',
#   '*',
#   'suspect'],
#  ['man',
#   'goe',
#   'airplan',
#   'engin',
#   'accid',
#   '//t.co/tyjxrfd3st',
#   'via',
#   'youtub'],
#  ['horribl',
#   'accid',
#   'man',
#   'die',
#   'wing',
#   'airplan',
#   '(',
#   '29-07-2015',
#   ')',
#   '//t.co/i7kztevb2v'],
#  ['girl', 'die', 'airplan', 'accid', 'fifteen', 'year', 'ago'],
#  ['mintechan',
#   'hihow',
#   '?',
#   'keio',
#   'line',
#   'stationright',
#   '?',
#   'btw',
#   'know',
#   'airplan',
#   'accid',
#   'near',
#   'chofu',
#   'airport',
#   'thi',
#   'week',
#   '?'],
#  ['cessna',
#   'airplan',
#   'accid',
#   'ocampo',
#   'coahuila',
#   'mexico',
#   'juli',
#   '29',
#   '2015',
#   'kill',
#   'four',
#   'men',
#   'includ',
#   'state',
#   'coahuila',
#   'govern',
#   'offici',
#   '.'],
#  ['horribl',
#   'accid',
#   'man',
#   'die',
#   'wing',
#   'airplan',
#   '(',
#   '29-07-2015',
#   ')',
#   'watchthevideo',
#   '//t.co/p64xrvgjik'],
#  ['expert',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'reunion',
#   'island',
#   '//t.co/lsmx2vwr3j',
#   'french',
#   'air',
#   'accid',
#   'expert',
#   'wednesdayâ\x89ã\x9b_'],
#  ['expert',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accid',
#   'expert',
#   'wednesday',
#   'began',
#   'examin',
#   '...'],
#  ['kca',
#   'votejkt48id',
#   'mbataweel',
#   'rip',
#   'binladen',
#   'famili',
#   'member',
#   'kill',
#   'airplan',
#   "'s",
#   'accid'],
#  ['almost',
#   'sent',
#   'cowork',
#   '*',
#   '*',
#   '*',
#   '*',
#   'accid',
#   'thank',
#   '*',
#   '*',
#   '*',
#   '*',
#   'airplan',
#   'mode'],
#  ['mexican',
#   'airplan',
#   'accid',
#   'ocampo',
#   'coahuila',
#   'mx',
#   '7/29/25',
#   'kill',
#   'coahuila',
#   'govern',
#   'subsecretariat',
#   'francisco',
#   'garcia',
#   'castel',
#   'age',
#   '42',
#   '.'],
#  ['mickinyman',
#   'theatlant',
#   'might',
#   'kill',
#   'airplan',
#   'accid',
#   'night',
#   'car',
#   'wreck',
#   '!',
#   'polit',
#   "'s",
#   'best',
#   '.'],
#  ['expert',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accid',
#   'expert',
#   '...',
#   '//t.co/tagzbcxfj0',
#   'mlb'],
#  ['horribl',
#   'accid',
#   'man',
#   'die',
#   'wing',
#   'airplaneã¥ã\x8a',
#   '(',
#   '29-07-2015',
#   ')',
#   '//t.co/5zrkzdhod'],
#  ['thi',
#   'unbeliev',
#   'insan',
#   '.',
#   'man',
#   'airport',
#   'airplan',
#   'aircraft',
#   'aeroplan',
#   'runway',
#   'accid',
#   'freakyâ\x89ã\x9b_',
#   '//t.co/cezhq7czl'],
#  ['horribl',
#   'accid',
#   '|',
#   'man',
#   'die',
#   'wing',
#   'airplaneã¥ã\x8a',
#   '(',
#   '29-07-2015',
#   ')',
#   '//t.co/wq3wjsgphl'],
#  ['horribl',
#   'accid',
#   'man',
#   'die',
#   'wing',
#   'airplan',
#   '(',
#   '29-07-2015',
#   ')',
#   '//t.co/tfcdronra6'],
#  ['usama',
#   'bin',
#   'ladin',
#   'famili',
#   'dead',
#   'airplan',
#   'crash',
#   '.',
#   'natur',
#   'accid',
#   '.'],
#  ['pilot',
#   'die',
#   'plane',
#   'crash',
#   'car',
#   'festiv',
#   '//t.co/kq9ae6ap2b',
#   'via',
#   'youtub',
#   'crash',
#   'aircraft',
#   'airplan',
#   'pilot',
#   'death',
#   'accid',
#   'carfest'],
#  ['god',
#   'accid',
#   'happen',
#   'thi',
#   'airplan',
#   'idc',
#   'rest',
#   'luggag',
#   'complet',
#   'destroy',
#   'pleas',
#   'save',
#   'makeup'],
#  ['horribl',
#   'accid',
#   'man',
#   'die',
#   'wing',
#   'airplan',
#   '(',
#   '29-07-2015',
#   ')',
#   '//t.co/hg8u2kr1rq'],
#  ['strict', 'liabil', 'context', 'airplan', 'accid', '-', '//t.co/gibyqhhkpk'],
#  ['dtn',
#   'brazil',
#   'expert',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accid',
#   'exp',
#   '...',
#   '//t.co/m9ig3wq8lq'],
#  ['updat',
#   'pictur',
#   'penn',
#   'twp',
#   '.',
#   'airplan',
#   'accid',
#   '.',
#   '//t.co/6jfgdnzrlc'],
#  ['see',
#   'judg',
#   'rule',
#   'thi',
#   '2009',
#   'accid',
#   'jfk',
#   'airport',
#   '?',
#   'involv',
#   'korean',
#   'air',
#   '?',
#   '.',
#   '//t.co/yh1cgln3rl',
#   '//t.co/6f5shpkjob'],
#  ['expert',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accid',
#   'expert',
#   'wedn',
#   '...',
#   '//t.co/v4smaeslk5'],
#  ['thugiauren', 'airplan', 'mode', 'accid', '?', '?'],
#  ['horribl',
#   'accid',
#   'man',
#   'die',
#   'wing',
#   'â\x89ã\x9bã\x8fairplaneâ\x89ã\x9bâ\x9d',
#   '29-07-2015',
#   '.',
#   '*',
#   '*',
#   '*',
#   '*',
#   'canâ\x89ã\x9bâªt',
#   'believ',
#   'eye',
#   'â\x89ã\x9bã\x92',
#   '...',
#   '//t.co/6ffylajwp'],
#  ['+',
#   'nicol',
#   'fletcher',
#   'one',
#   'victim',
#   'crash',
#   'airplan',
#   'time',
#   'ago',
#   '.',
#   'accid',
#   'left',
#   'littl',
#   'bit',
#   'trauma',
#   '.',
#   'although',
#   "'s",
#   '+'],
#  ['36',
#   'year',
#   'ago',
#   'today',
#   'basebal',
#   'lost',
#   'one',
#   'great',
#   'airplan',
#   'accid',
#   '.',
#   'rip',
#   'captain',
#   '.',
#   'yanke',
#   'yanke',
#   '//t.co/inku28vjjj'],
#  ['expert',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accid',
#   'expert',
#   'wedn',
#   '...',
#   '//t.co/miw2i0pqxz'],
#  ['*',
#   '*',
#   '*',
#   '*',
#   'horribl',
#   'accid',
#   'man',
#   'die',
#   'wing',
#   'airplan',
#   '.',
#   '//t.co/xdxdprcpn'],
#  ['breakingnew',
#   'expert',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accid',
#   'e',
#   '...',
#   '//t.co/3xicuvlvlj'],
#  ['*',
#   '*',
#   '*',
#   '*',
#   '!',
#   "n't",
#   'believ',
#   'thi',
#   '.',
#   'rip',
#   'bro',
#   'airplan',
#   'accid',
#   'jetengin',
#   'turbojet',
#   'bo',
#   'g90',
#   '//t.co/kxxnszp6nk'],
#  ['expert',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accid',
#   'expert',
#   'wednesday',
#   'began',
#   'examin',
#   '...'],
#  ['expert',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accid',
#   'expert',
#   'wedn',
#   '...',
#   '//t.co/kubsm16oud'],
#  ['airplan', 'accid', '.'],
#  ['phone',
#   'look',
#   'like',
#   'wa',
#   'car',
#   'ship',
#   'airplan',
#   'accid',
#   '.',
#   'terribl'],
#  ['statist',
#   "'m",
#   'risk',
#   'get',
#   'kill',
#   'cop',
#   'die',
#   'airplan',
#   'accid',
#   '.'],
#  ['airplan',
#   'crash',
#   'hous',
#   'colombia',
#   '12',
#   'peopl',
#   'die',
#   'accid',
#   '//t.co/zhjlflbhzl'],
#  ['shoot', 'airplan', 'accid', '//t.co/iecc1jdoub'],
#  ['could',
#   'drone',
#   'caus',
#   'airplan',
#   'accid',
#   '?',
#   'pilot',
#   'worri',
#   'use',
#   'drone',
#   'esp',
#   '.',
#   'close',
#   'vicin',
#   'airport',
#   '//t.co/kz35rgngjf'],
#  ['earli',
#   'wake',
#   'call',
#   'sister',
#   'beg',
#   'come',
#   '&',
#   'amp',
#   ';',
#   'ride',
#   'w/her',
#   'ambul',
#   'hospit',
#   'rodkiai'],
#  ['//t.co/ay6zzcupnz',
#   'twelv',
#   'fear',
#   'kill',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   '//t.co/sc9dns41mc'],
#  ['two',
#   'air',
#   'ambul',
#   'scene',
#   'seriou',
#   'crash',
#   'two',
#   'car',
#   'lorri',
#   '...',
#   '-',
#   '//t.co/9pfeaqeski',
#   '//t.co/fntg70rnkx',
#   '|',
#   'emsneâ\x89ã\x9b_'],
#  ['twelv',
#   'fear',
#   'kill',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   '-',
#   'reuter',
#   '//t.co/mdnugvubwn',
#   'yugvani'],
#  ['twelv',
#   'fear',
#   'kill',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   '//t.co/zdsug0ujs7'],
#  ['lead',
#   'emerg',
#   'servic',
#   'boss',
#   'welcom',
#   'new',
#   'ambul',
#   'chariti',
#   '//t.co/mj2jq2psv6'],
#  ['anyon',
#   'travel',
#   'aberystwyth-shrewsburi',
#   'right',
#   "'s",
#   'incid',
#   '.',
#   'servic',
#   'halt',
#   'outsid',
#   'shrew',
#   '.',
#   'ambul',
#   'scene',
#   '.'],
#  ['twelv',
#   'fear',
#   'kill',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   '//t.co/xum8ylcb4q'],
#  ['ambul',
#   'sprinter',
#   'automat',
#   'frontlin',
#   'vehicl',
#   'choic',
#   '14',
#   '*',
#   '*',
#   '*',
#   '*',
#   'compliant',
#   '|',
#   'ebay',
#   '//t.co/4evttqpeia'],
#  ['//t.co/q5xtkakm08',
#   "'m",
#   'dy',
#   'send',
#   'ambul',
#   'm__belli',
#   'brightasastar_'],
#  ['new',
#   'nanotech',
#   'devic',
#   'abl',
#   'target',
#   'destroy',
#   'blood',
#   'clot',
#   '//t.co/hfy5v3slbb'],
#  ['ambul',
#   'sprinter',
#   'automat',
#   'frontlin',
#   'vehicl',
#   'choic',
#   '14',
#   '*',
#   '*',
#   '*',
#   '*',
#   'compliant',
#   '|',
#   'ebay',
#   '//t.co/7x3pddbt0z'],
#  ['20skyhawkmm20',
#   'traplord_29',
#   'fredosantana300',
#   'lilreese300',
#   'wa',
#   'hella',
#   'crazi',
#   '3',
#   'fight',
#   'ambul',
#   'coupl',
#   'mosh',
#   'pit',
#   '?',
#   '?'],
#  ['disneyxrowbrina',
#   'ambul',
#   "n't",
#   'even',
#   'park',
#   'well',
#   'like',
#   'nearli',
#   'top',
#   'someon',
#   "'s",
#   'car',
#   "'m",
#   'laugh'],
#  ['get', 'run', 'ambul', 'lucki', '?', 'justsay', 'randomthought'],
#  ['news',
#   'twelv',
#   'fear',
#   'kill',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   '//t.co/bfes5twbzt',
#   'til_now',
#   'dna'],
#  ['//t.co/7xglah10zl',
#   'twelv',
#   'fear',
#   'kill',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   '//t.co/thmblaatzp'],
#  ['tanslash', 'wait', 'ambul'],
#  ['fouseytub',
#   'ok',
#   '?',
#   'need',
#   'ambul',
#   '.',
#   'hahahah',
#   'wa',
#   'good',
#   '!',
#   '//t.co/zsberqnn9n'],
#  ['ambul',
#   'sprinter',
#   'automat',
#   'frontlin',
#   'vehicl',
#   'choic',
#   '14',
#   '*',
#   '*',
#   '*',
#   '*',
#   'compliant',
#   '|',
#   'ebay',
#   '//t.co/q8ivrzojzv'],
#  ['pakistan',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   'kill',
#   'nine',
#   '//t.co/8e7ry8ebmf'],
#  ['thenissonian',
#   'rejectdcartoon',
#   'nissan',
#   'ok',
#   'need',
#   'medic',
#   'istanc',
#   'call',
#   'ambul',
#   'need'],
#  ['ems1',
#   'ny',
#   'emt',
#   'petit',
#   '$',
#   '17',
#   'per',
#   'hour',
#   'â\x89ã\x9bã·minimum',
#   'wageâ\x89ã\x9bâª',
#   '//t.co/4oa6swlxmr',
#   'em',
#   'paramed',
#   'ambul'],
#  ['//t.co/fcqmkffflw',
#   'twelv',
#   'fear',
#   'kill',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   '//t.co/vayaymbngu'],
#  ['twelv',
#   'fear',
#   'kill',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   '//t.co/3brme6sn4t'],
#  ['ambul',
#   'sprinter',
#   'automat',
#   'frontlin',
#   'vehicl',
#   'choic',
#   '14',
#   '*',
#   '*',
#   '*',
#   '*',
#   'compliant',
#   '|',
#   'ebay',
#   '//t.co/ujrx9kgawp'],
#  ['ambul',
#   'sprinter',
#   'automat',
#   'frontlin',
#   'vehicl',
#   'choic',
#   '14',
#   '*',
#   '*',
#   '*',
#   '*',
#   'compliant',
#   '|',
#   'ebay',
#   '//t.co/kp2lf4aut'],
#  ['kiwi_karyn',
#   'check',
#   "'s",
#   'park',
#   'lot',
#   '!',
#   '!',
#   'said',
#   'last',
#   'year',
#   'wa',
#   'ambul',
#   'st',
#   'john',
#   '.',
#   '//t.co/hpvodud7ip'],
#  ["n't", 'know', 'way', 'ambul', 'come', '&', 'lt', ';', '&', 'lt', ';'],
#  ['shot',
#   '12',
#   'time',
#   '.',
#   'found',
#   'dead',
#   'cuff',
#   'involv',
#   'car',
#   'accid',
#   '.',
#   'offic',
#   'told',
#   'ambul',
#   'treat',
#   '.',
#   '//t.co/meudjwaang'],
#  ['reuter',
#   'twelv',
#   'fear',
#   'kill',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   '//t.co/shzpyiqok5'],
#  ['//t.co/pwwpum6rbj',
#   'twelv',
#   'fear',
#   'kill',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   '//t.co/yspon4d6qo'],
#  ['margaretcho',
#   'call',
#   '*',
#   '*',
#   '*',
#   '*',
#   "'m",
#   'go',
#   'call',
#   'ambul',
#   ')',
#   'rainbowpow'],
#  ['whi', 'ambul', 'right', 'outsid', 'work'],
#  ['â\x89ã\x9bã\x8f',
#   'leoblakecart',
#   'thi',
#   'dog',
#   'think',
#   "'s",
#   'ambul',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '//t.co/mg1lpgr0rmâ\x89ã\x9bâ\x9d',
#   'natasha_rideout'],
#  ['happen',
#   '-',
#   'hatzolah',
#   'em',
#   'ambul',
#   'respond',
#   'dual',
#   'siren',
#   'andâ\x89ã\x9b_',
#   '//t.co/sek6mq6njf'],
#  ['new',
#   'nanotech',
#   'devic',
#   'abl',
#   'target',
#   'destroy',
#   'blood',
#   'clot',
#   '//t.co/mnmyjxq9go',
#   'scienc'],
#  ['//t.co/fuerk0gwui',
#   'twelv',
#   'fear',
#   'kill',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   '//t.co/mv7ggglmvc'],
#  ['vballplaya2296',
#   'want',
#   'send',
#   'medic',
#   'suppli',
#   'dad',
#   "'s",
#   'ambul',
#   '?'],
#  ['//t.co/x5yeuylt1x',
#   'twelv',
#   'fear',
#   'kill',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   '//t.co/2ugrmd1z1n'],
#  ['2',
#   'held',
#   '*',
#   '*',
#   '*',
#   '*',
#   'ambul',
#   '//t.co/d9sowi1g21',
#   '//t.co/opxmdpiwau'],
#  ['twelv',
#   'fear',
#   'kill',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   '//t.co/th9ywbbeet',
#   'worldnew'],
#  ['//t.co/b2fasrt1tn',
#   'twelv',
#   'fear',
#   'kill',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   '//t.co/o8bjxnepqm'],
#  ['twelv',
#   'fear',
#   'kill',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   '//t.co/x2qsjod40u',
#   'worldnew'],
#  ["'s",
#   'polic',
#   'ambul',
#   'number',
#   'lesotho',
#   '?',
#   'ani',
#   'bodi',
#   'know',
#   '?'],
#  ['medic914',
#   'aace_org',
#   'surpris',
#   'still',
#   'standardis',
#   'clinic',
#   'practic',
#   'across',
#   '11',
#   'nh',
#   'ambul',
#   'trust',
#   '.'],
#  ['whi',
#   'helicopt',
#   'ambul',
#   'ride',
#   'transfer',
#   'hospit',
#   '21',
#   'mile',
#   'away',
#   'cost',
#   '$',
#   '29800',
#   '?',
#   '//t.co/7zqirey7t',
#   '//t.co/9qp3pqpwzv'],
#  ['//t.co/j8tyt1xrrk',
#   'twelv',
#   'fear',
#   'kill',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   '//t.co/9d4nazoi94'],
#  ['peopl', 'tri', 'j-walk', 'ambul', 'ping', '...', 'hate', '.'],
#  ['privileg',
#   'proud',
#   'wear',
#   'thi',
#   'uniform.',
#   '?',
#   '?',
#   'nh',
#   'ambul',
#   'gayuk',
#   'uniform',
#   'proud',
#   'privileg',
#   'whatsyouremerg',
#   '//t.co/0bkmuhysfx'],
#  ['episod',
#   'trunk',
#   'annihil',
#   'freiza',
#   'cleanest',
#   '*',
#   '*',
#   '*',
#   '*',
#   'ever',
#   '.',
#   'show',
#   '*',
#   '*',
#   '*',
#   '*',
#   'merci',
#   '.'],
#  ['shall',
#   'annihil',
#   'petebest',
#   'dessic',
#   'laid',
#   'bare',
#   '.',
#   'shall',
#   'kneel',
#   'befor',
#   '.'],
#  ['urib', 'annihil', 'basebal', '.', 'met'],
#  ['marksmaponyan',
#   'hey',
#   '!',
#   'sundown',
#   'annihil',
#   'previou',
#   'meet',
#   'celtic.inde',
#   'improv',
#   '.'],
#  ['bartend',
#   'work',
#   'describ',
#   '*',
#   '*',
#   '*',
#   '*',
#   'man',
#   'annihil',
#   'kdunning1919',
#   'hsnowberg',
#   'gabrielasmith29',
#   '.',
#   '16',
#   'day'],
#  ['volfan326',
#   'tneazzi',
#   'mizzou',
#   'ha',
#   'annihil',
#   'florida',
#   'past',
#   '2',
#   'season',
#   'even',
#   'end',
#   'muschamp',
#   "'s",
#   'career',
#   'ca',
#   "n't",
#   'compet',
#   'bama'],
#  ['annihil', 'ab', '.', '?', '?', '//t.co/1xpw292tj'],
#  ['annihil',
#   'statu',
#   'educ',
#   'mba',
#   'behalf',
#   'easi',
#   'street',
#   'careen',
#   'eovm',
#   '//t.co/e0pi0c54ff'],
#  ['cop',
#   'pull',
#   '*',
#   '*',
#   '*',
#   '*',
#   'driver',
#   'safeti',
#   'second',
#   'befor',
#   'hi',
#   'car',
#   'hit',
#   'train',
#   '.',
#   '//t.co/ctl5xzihxaã¥ã\x8a',
#   '//t.co/1kdoztd9mv',
#   'via',
#   'viralspel'],
#  ['cop',
#   'pull',
#   '*',
#   '*',
#   '*',
#   '*',
#   'driver',
#   'safeti',
#   'second',
#   'befor',
#   'hi',
#   'car',
#   'hit',
#   'train',
#   '.',
#   '//t.co/cssc8hcsxnã¥ã\x8a',
#   '//t.co/jblgylcsay',
#   'via',
#   'viralspel'],
#  ['rosiegray',
#   'sincereti',
#   'think',
#   'un',
#   'would',
#   'move',
#   'israel',
#   'wa',
#   'fraction',
#   'chanc',
#   'annihil',
#   '?'],
#  ['*',
#   'luka',
#   '*',
#   'die',
#   '!',
#   '!',
#   'everyth',
#   'annihil',
#   '!',
#   '-',
#   'aloi',
#   'tranci'],
#  ['johnboywest',
#   'onli',
#   "'stage",
#   "'",
#   'drama',
#   'queen',
#   'stand',
#   'drama',
#   'stage',
#   '&',
#   'amp',
#   ';',
#   'certainli',
#   'never',
#   'world',
#   'stage',
#   ';',
#   'would',
#   'annihil',
#   '.'],
#  ['acarewornheart',
#   'good',
#   'un',
#   'fella',
#   'sorri',
#   'wo',
#   "n't",
#   'get',
#   'annihil',
#   '('],
#  ['cop',
#   'pull',
#   '*',
#   '*',
#   '*',
#   '*',
#   'driver',
#   'safeti',
#   'second',
#   'befor',
#   'hi',
#   'car',
#   'hit',
#   'train',
#   '.',
#   '//t.co/thrhkhogcuã¥ã\x8a',
#   '//t.co/tzszmf2qx',
#   'via',
#   'viralspel'],
#  ['_drodrolagi',
#   'handplacementgo',
#   'bro',
#   'annihil',
#   'hashtag',
#   'thi',
#   'week',
#   '.'],
#  ['must', 'annihil', '!'],
#  ['cop',
#   'pull',
#   '*',
#   '*',
#   '*',
#   '*',
#   'driver',
#   'safeti',
#   'second',
#   'befor',
#   'hi',
#   'car',
#   'hit',
#   'train',
#   '.',
#   '//t.co/c0nkgp6w03ã¥ã\x8a',
#   '//t.co/imwmfdjssn',
#   'via',
#   'viralspel'],
#  ['boom',
#   '!',
#   'countri',
#   'wa',
#   'entir',
#   'annihil',
#   'hâ\x89ã\x9b_',
#   'â\x89ã\x9bã\x93',
#   'britain',
#   '//t.co/irfcn71szv'],
#  ['amirkingkhan',
#   'would',
#   'annihil',
#   'might',
#   'well',
#   'thank',
#   'floydmayweath'],
#  ['one',
#   'thing',
#   'sure-',
#   '*',
#   '*',
#   '*',
#   '*',
#   'ha',
#   'promis',
#   'israel',
#   'annihil',
#   '.',
#   '...',
#   'horror',
#   'iran',
#   'w/nuke',
#   '.',
#   '//t.co/xn09mx6sxi'],
#  ['step', 'outsid', '5', 'second', 'get', 'annihil', 'mosquito', '?'],
#  ['violentfeminazi',
#   'guess',
#   "'s",
#   'ok',
#   'armenian',
#   'sinc',
#   "'ve",
#   'spent',
#   'histori',
#   'get',
#   'annihil'],
#  ['jacksfilm',
#   'yiayplan',
#   'well',
#   'first',
#   'strike',
#   'dreamwork',
#   'minion',
#   'annihil',
#   '.'],
#  ['70',
#   'year',
#   'sinc',
#   'annihil',
#   '100000',
#   'peopl',
#   'instantli',
#   'becam',
#   'awar',
#   'abil',
#   'annihil',
#   'whole',
#   'human'],
#  ['day',
#   '1',
#   'tryout',
#   'went',
#   'good',
#   'minu',
#   'fact',
#   'stop',
#   'quickli',
#   'get',
#   'short',
#   'ball',
#   'annihil',
#   'toenail',
#   'injuri',
#   'even'],
#  ['dure',
#   '1960',
#   'oryx',
#   'symbol',
#   'arabian',
#   'peninsula',
#   'annihil',
#   'hunter',
#   '.',
#   '//t.co/yangeqbuqw',
#   '//t.co/jq2eh5kglt'],
#  ["'if",
#   'natur',
#   'appropri',
#   'love',
#   'burn',
#   'becom',
#   'annihil',
#   'belov',
#   '...',
#   "'",
#   '//t.co/smlwjund09'],
#  ['ninahoag',
#   '-',
#   "'if",
#   'shred',
#   'psych',
#   'work',
#   'friendship',
#   'would',
#   'annihil',
#   "'"],
#  ['thehil',
#   'thi',
#   '1',
#   'exampl',
#   'conserv',
#   'annihil',
#   'burton',
#   'v',
#   'wiimington',
#   'prkng',
#   'auth',
#   'liber',
#   'stood',
#   '&',
#   'amp',
#   ';',
#   'done',
#   'noth'],
#  ['aug',
#   '3',
#   '1915â\x89ã\x9bã\x93kaiserjaeg',
#   'wipe',
#   '.',
#   ';',
#   'franci',
#   'joseph',
#   "'s",
#   'crack',
#   'regiment',
#   'annihil',
#   'carso',
#   'plateau',
#   '.',
#   '//t.co/d1spswl66h'],
#  ['(',
#   'luka',
#   ')',
#   "'they",
#   'die',
#   '!',
#   '!',
#   'everyth',
#   'annihil',
#   '!',
#   "'",
#   '-',
#   'aloi',
#   'tranci',
#   '-'],
#  ['readi', 'get', 'annihil', 'buc', 'game'],
#  ['philipduncan',
#   'breakfaston',
#   'peopl',
#   "'annihil",
#   'last',
#   'night',
#   'weather',
#   "'",
#   '...',
#   'realli',
#   'philip',
#   'thought',
#   'would',
#   'forecast',
#   '...'],
#  ['domain', 'sophist', 'annihil', 'close', 'up-to-the-minut', 'feat', 'zrnf'],
#  ['stormbeard',
#   'steel_lord',
#   'seen',
#   'juda',
#   'priest',
#   '2005',
#   'rob',
#   'came',
#   'back',
#   ';',
#   'scorpion',
#   'support',
#   '.',
#   '*',
#   '*',
#   '*',
#   '*',
#   'annihil',
#   'place',
#   '.',
#   'astonish',
#   'gig'],
#  ['offici',
#   'skip',
#   'fantasticfour/',
#   'fant4stic/whatev',
#   'hashtag',
#   '.',
#   "'s",
#   'get',
#   'annihil',
#   'review',
#   '.',
#   'bummer',
#   '.'],
#  ['die', '!', '!', 'everyth', 'annihil', '!'],
#  ['tomcatart',
#   'thu',
#   'explain',
#   'whi',
#   'annihil',
#   '.',
#   'thi',
#   'case',
#   'onli',
#   'survivor',
#   'evolv',
#   'becam',
#   'godlik'],
#  ['complet', 'annihil', 'cech', 'paul', 'keegan', 'time', 'aliv'],
#  ['tomcatart',
#   "'who",
#   'annihil',
#   'legion',
#   '.',
#   'survivor',
#   'imperfect',
#   'hybrid',
#   'project',
#   'quickli',
#   'form',
#   'new',
#   'secret',
#   'cell'],
#  ['sirbrandonknt',
#   'exactli',
#   '.',
#   "'s",
#   'whi',
#   'lesnar/cena',
#   'match',
#   'summerslam',
#   'last',
#   'year',
#   'wa',
#   'great',
#   'becaus',
#   'brock',
#   'annihil',
#   'guy',
#   "'s"],
#  ['cop',
#   'pull',
#   '*',
#   '*',
#   '*',
#   '*',
#   'driver',
#   'safeti',
#   'second',
#   'befor',
#   'hi',
#   'car',
#   'hit',
#   'train',
#   '.',
#   '//t.co/f1bakpnyn6ã¥ã\x8a',
#   '//t.co/lzxwoaye4x',
#   'via',
#   'viralspel'],
#  ['brooo', 'got', 'annihil', '//t.co/ur7qkqg1wf'],
#  ['annihil',
#   'damascu',
#   'syrian',
#   'armi',
#   'grind',
#   'â\x89ã\x9bã·alloosh',
#   'hi',
#   'gang',
#   'manur',
#   'pile',
#   '//t.co/7rakhp3bwm'],
#  ['thatd',
#   'ok',
#   'wa',
#   "n't",
#   'complet',
#   'forthright',
#   'may',
#   'also',
#   'food',
#   'coma',
#   'bc',
#   'kebab/tahini/pickl',
#   'also',
#   'annihil',
#   'w/fri'],
#  ['albertbr', 'wa', 'probabl', 'annihil', 'need', 'hi', 'dd'],
#  ['$',
#   'gmcr',
#   'long',
#   'rgreen',
#   'mountain',
#   'red',
#   'mountain',
#   '...',
#   'stock',
#   'annihil',
#   'hour'],
#  ['fun',
#   'fill',
#   'happy-hour',
#   'simmon',
#   'bar',
#   'camden',
#   'thi',
#   'handsom',
#   'one',
#   '?',
#   '?',
#   '(',
#   'got',
#   'annihil',
#   'apart',
#   'thi',
#   'game',
#   ')',
#   '//t.co/4jno677zkv'],
#  ['juanni', 'beisbol', 'sr.', 'annihil', 'ball', '.', 'lgm'],
#  ['rvfriedmann',
#   '*',
#   '*',
#   '*',
#   '*',
#   'fraction',
#   'hi',
#   'belief',
#   'total',
#   'annihil',
#   'destruct',
#   'usa',
#   'lodisilverado',
#   'ritzy_jewel'],
#  ['potu',
#   'mayb',
#   'call',
#   'israel',
#   'tell',
#   "'re",
#   'sorri',
#   'pre',
#   'ha',
#   'sold',
#   'river',
#   'annihil',
#   '.'],
#  ['evildead', '-', 'annihil', 'civil', '//t.co/spfke5kqu4'],
#  ['u.',
#   'nation',
#   'park',
#   'servic',
#   'tonto',
#   'nation',
#   'forest',
#   'stop',
#   'annihil',
#   'salt',
#   'river',
#   'wild',
#   'hors',
#   '...',
#   '//t.co/6lojoorouk',
#   'via',
#   'chang'],
#  ['pleas',
#   'sign',
#   '&',
#   'amp',
#   ';',
#   'rt',
#   'save',
#   'saltriverwildhors',
#   '//t.co/gb8ispiarp',
#   '//t.co/bx0l87inc8'],
#  ['alli',
#   'plan',
#   'annihil',
#   'german',
#   'peopl',
#   '//t.co/ruhxglo18q',
#   '//t.co/hbupkzwdwq',
#   'loui',
#   'nizer',
#   '-',
#   'veri',
#   'interest',
#   '...'],
#  ['annihil', 'quarterstaff', 'annihil'],
#  ['world',
#   'annihil',
#   'vs',
#   'self',
#   'transform',
#   '//t.co/pyehwodwun',
#   'alien',
#   'attack',
#   'extermin',
#   'human',
#   '//t.co/pb2n77nskz'],
#  ['starmad',
#   'stardat',
#   '3',
#   'planetari',
#   'annihil',
#   '//t.co/i2hhviumtm',
#   'via',
#   'youtub'],
#  ['u.',
#   'nation',
#   'park',
#   'servic',
#   'tonto',
#   'nation',
#   'forest',
#   'stop',
#   'annihil',
#   'salt',
#   'river',
#   'wild',
#   'hors',
#   '...',
#   '//t.co/m8mvdspjp7',
#   'via',
#   'chang'],
#  ['u.',
#   'nation',
#   'park',
#   'servic',
#   'tonto',
#   'nation',
#   'forest',
#   'stop',
#   'annihil',
#   'salt',
#   'river',
#   'wild',
#   'hors',
#   '...',
#   '//t.co/sw1sbua3mn',
#   'via',
#   'chang'],
#  ['pleas',
#   'share',
#   'sign',
#   'thi',
#   'petit',
#   'save',
#   'wild',
#   'hors',
#   'arizona',
#   '.',
#   '//t.co/3tssxphuf'],
#  ['kimkardashian',
#   'pleas',
#   'sign',
#   'share',
#   'thi',
#   'petit',
#   'save',
#   'wild',
#   'hors',
#   'arizona',
#   '.',
#   '//t.co/3tssxphuf',
#   '?',
#   '?',
#   '?',
#   '?'],
#  ['u.',
#   'nation',
#   'park',
#   'servic',
#   'tonto',
#   'nation',
#   'forest',
#   'stop',
#   'annihil',
#   'salt',
#   'river',
#   'wild',
#   'hors',
#   '...',
#   '//t.co/latvr8rzck',
#   'via',
#   'chang'],
#  ['u.',
#   'nation',
#   'park',
#   'servic',
#   'tonto',
#   'nation',
#   'forest',
#   'stop',
#   'annihil',
#   'salt',
#   'river',
#   'wild',
#   'hors',
#   '...',
#   '//t.co/kpqk0c4g0m',
#   'via',
#   'chang'],
#  ['theellenshow',
#   'pleas',
#   'check',
#   'salt',
#   'river',
#   'hors',
#   'help',
#   'stop',
#   'annihil',
#   'happen',
#   'without',
#   '54000',
#   'signatures.chang',
#   '.org',
#   'thx'],
#  ['new', '!', 'soul', 'punish', 'annihil', '?', '//t.co/cmnv6vyfcq'],
#  ['soul',
#   'punish',
#   'withã¥ã\x8aannihil',
#   '?',
#   '//t.co/c1qxjweqqu',
#   '//t.co/zhp0sowxri'],
#  ['calfreedommom',
#   'steph93065',
#   'mention',
#   'major',
#   'contributor',
#   'annihil',
#   'israel'],
#  ['willienelson',
#   'need',
#   'help',
#   '!',
#   'hors',
#   'die',
#   '!',
#   'pleas',
#   'rt',
#   '&',
#   'amp',
#   ';',
#   'sign',
#   'petit',
#   '!',
#   'take',
#   'stand',
#   '&',
#   'amp',
#   ';',
#   'voic',
#   '!',
#   'gilbert23',
#   '//t.co/e8dl1lncvu'],
#  ['*',
#   '*',
#   '*',
#   'latest',
#   'updat',
#   'salt',
#   'river',
#   'wild',
#   'hors',
#   'round-up',
#   '*',
#   '*',
#   '*',
#   '//t.co/wjscdvcevh',
#   'via',
#   'chang'],
#  ['u.',
#   'nation',
#   'park',
#   'servic',
#   'tonto',
#   'nation',
#   'forest',
#   'stop',
#   'annihil',
#   'salt',
#   'river',
#   'wild',
#   'hors',
#   '...',
#   '//t.co/w5rhtuey90',
# ...
#  ['like',
#   'youtub',
#   'video',
#   '//t.co/xo2zbpbjb3',
#   'fema',
#   'region',
#   'iii',
#   'target',
#   'bioterror',
#   '!',
#   '!',
#   '!',
#   'nasa',
#   '-',
#   'japan',
#   'rocket',
#   'launch',
#   'lithium'],
#  ['anthrax',
#   'bioterror',
#   'cdc',
#   'carri',
#   'extens',
#   'review',
#   'lab',
#   'safeti',
#   'pathogen',
#   'handl',
#   'procedur',
#   '//t.co/bclqpwfdod'],
#  ['firepow',
#   'lab',
#   '[',
#   'electron',
#   'resourc',
#   ']',
#   'autom',
#   'fight',
#   'infecti',
#   'diseas',
#   'bioterror',
#   '/â\x89ã\x9b_',
#   '//t.co/kvpbybglsr'],
#  ['cagov',
#   '90blk',
#   '&',
#   'amp',
#   ';',
#   '8wht',
#   'collud',
#   '2',
#   'take',
#   'wht',
#   'f',
#   'usagov',
#   'auth',
#   'hostag',
#   '&',
#   'amp',
#   ';',
#   '2',
#   'make',
#   'look',
#   'blk',
#   'w/bioterror',
#   '&',
#   'amp',
#   ';',
#   'use',
#   'lgl/org',
#   'idi',
#   'id',
#   'still',
#   '?',
#   'vp'],
#  ['darrellissa',
#   'doe',
#   "'great",
#   'iran',
#   'deal',
#   "'",
#   'cover',
#   'bioterror',
#   '?',
#   'got',
#   'cut',
#   'terribl',
#   '.',
#   'keep',
#   'good',
#   'work',
#   '.'],
#  ['time',
#   'hedg',
#   'catastroph',
#   'risk',
#   'climat',
#   'chang',
#   'asteroid',
#   'impact',
#   'bioterror',
#   '?',
#   '//t.co/hq6wqsgsjx'],
#  ['tale',
#   'two',
#   'pox',
#   '-',
#   'bodi',
#   'horror',
#   '//t.co/w2ixt1k0ab',
#   'viru',
#   'infectiousdiseas',
#   'bioterror'],
#  ['uscourt',
#   '90blk',
#   '&',
#   'amp',
#   ';',
#   '8wht',
#   'collud',
#   '2',
#   'take',
#   'wht',
#   'f',
#   'usagov',
#   'auth',
#   'hostag',
#   '&',
#   'amp',
#   ';',
#   '2',
#   'make',
#   'look',
#   'blk',
#   'w/bioterror',
#   '&',
#   'amp',
#   ';',
#   'use',
#   'lgl/org',
#   'idi',
#   'id',
#   'still',
#   '?'],
#  ['bioterror',
#   'public',
#   'health',
#   'superbug',
#   'biolab',
#   'epidem',
#   'biosurveil',
#   'outbreak',
#   '|',
#   'homeland',
#   'secur',
#   'new',
#   'wire',
#   '//t.co/cvhygwcbzv'],
#  ['creation',
#   'ai',
#   'climat',
#   'chang',
#   'bioterror',
#   'autom',
#   'workforc',
#   'contact',
#   'life',
#   'wealth',
#   'inequ',
#   'yea',
#   "'ve",
#   'got',
#   'easi'],
#  ['lie',
#   'trust',
#   'dvd',
#   'cia',
#   'hollywood',
#   'bioterror',
#   '*',
#   '*',
#   '*',
#   '*',
#   'horowitz',
#   'vaccin',
#   'nwo',
#   '//t.co/6pagjqfbzk',
#   '//t.co/qzizelxbyr'],
#  ['o_magazin',
#   'satan',
#   "'s",
#   'daughter',
#   'shadow',
#   'warrior',
#   '50ft',
#   'women',
#   'aka',
#   'transgend',
#   'mode',
#   'ps',
#   'nyc',
#   'fold',
#   'extra',
#   'extra',
#   'center',
#   'bioterror'],
#  ['drrichardbess',
#   'ye',
#   '.',
#   'would',
#   'think',
#   '.',
#   'sinc',
#   'colleg',
#   '88-92',
#   "'s",
#   'difficult',
#   'think',
#   'bioterror',
#   'esp',
#   '.',
#   'bc',
#   "'dispers",
#   '.',
#   "'"],
#  ['volunt',
#   'need',
#   'particip',
#   'emerg',
#   'prepared',
#   'drill',
#   'simul',
#   'bioterror',
#   'disast',
#   '//t.co/nwv2rvghf3',
#   'hvnewsnetwork'],
#  ['meyerbjoern',
#   'thelonevirolog',
#   'mackayim',
#   'major',
#   'american',
#   'newspap',
#   'run',
#   'seri',
#   'alleg',
#   'bioterror',
#   'research',
#   'go',
#   '2/n'],
#  ['bioterror',
#   'guidelin',
#   'medic',
#   'public',
#   'health',
#   'manag',
#   '(',
#   '2002',
#   ')',
#   '//t.co/zkuxhnobag',
#   '//t.co/fhgkyxffu5'],
#  ['fight', 'bioterror', 'sir', '.'],
#  ['cdc', 'ha', 'pretti', 'cool', 'list', 'bioterror', 'agent', ':3'],
#  ['bbcworld', 'bioterror', 'drone', 'reach', 'larg', 'popul', 'erea', '.'],
#  ['bishoyragheb',
#   'fair',
#   '.',
#   'bioterror',
#   'way',
#   'go',
#   '.',
#   'doe',
#   'mean',
#   'bsc',
#   "n't",
#   'irrelev',
#   '?'],
#  ['govern',
#   'expert',
#   'concern',
#   'possibl',
#   'bioterror',
#   'use',
#   'gm',
#   'organ',
#   'scientist',
#   'concern',
#   '...',
#   '//t.co/sume5pro0f'],
#  ['doe',
#   'thi',
#   'prepar',
#   'us',
#   '?',
#   'hh',
#   'select',
#   '9',
#   'region',
#   'special',
#   'pathogen',
#   'treatment',
#   'center',
#   'bioterror',
#   'infecti',
#   'ebola',
#   '//t.co/qmo1txxdkj'],
#  ['debtin', 'forget', 'threat', 'bioterror', '.'],
#  ['stationcdrkelli',
#   'ani',
#   'support',
#   'sy',
#   '4',
#   'usagov',
#   'auth',
#   'taken',
#   'hostag',
#   'blk',
#   'us',
#   'clergyforc',
#   '2',
#   'exist',
#   'younger',
#   '&',
#   'amp',
#   ';',
#   'grossli',
#   'disfigur',
#   'bioterror',
#   '?',
#   'ap'],
#  ['70',
#   '70',
#   '...',
#   '&',
#   'amp',
#   ';',
#   'think',
#   'possibl',
#   'full',
#   'transform',
#   'imposs',
#   '.',
#   "n't",
#   'quit',
#   'like',
#   'medic',
#   'mysteri',
#   '.',
#   'bioterror',
#   'suck',
#   '.'],
#  ['fight', 'bioterror', 'sir', '.'],
#  ['hst',
#   "'s",
#   'anthoni',
#   'kimeri',
#   'discuss',
#   'bioterror',
#   'syfi',
#   'channel',
#   "'s",
#   "'joe",
#   'rogan',
#   'question',
#   'everyth',
#   "'",
#   'pathogen',
#   'viru',
#   '//t.co/0fdsc3f2iw'],
#  ['anthoni',
#   'kimeri',
#   'discuss',
#   'bioterror',
#   'syfi',
#   'channel',
#   "'s",
#   "'joe",
#   'rogan',
#   'question',
#   'everyth',
#   "'",
#   '//t.co/zckjwacrc'],
#  ['harvardu',
#   '90blk',
#   '&',
#   'amp',
#   ';',
#   '8wht',
#   'collud',
#   '2',
#   'take',
#   'wht',
#   'f',
#   'usagov',
#   'auth',
#   'hostag',
#   '&',
#   'amp',
#   ';',
#   '2',
#   'make',
#   'look',
#   'blk',
#   'w/bioterror',
#   '&',
#   'amp',
#   ';',
#   'use',
#   'lgl/org',
#   'idi',
#   'id',
#   'still',
#   '?'],
#  ['book',
#   'describ',
#   'futur',
#   'therapi',
#   'technolog',
#   'sport',
#   'sexual',
#   'bioterror',
#   'diagnosi',
#   '?',
#   'digitalhealth',
#   'hcsm'],
#  ['aphiabeta1907',
#   'w/ugli',
#   'due',
#   '2',
#   "'ugli",
#   "'",
#   'amesocialact',
#   'frat',
#   "'s",
#   'bioterrorismi',
#   "'m",
#   "'s",
#   'fbi',
#   'id',
#   'u',
#   '$',
#   'tolew',
#   "'",
#   'g',
#   'anoth',
#   'home',
#   '.',
#   'abc'],
#  ['uganda', 'seen', 'front', 'line', 'bioterror', 'fight'],
#  ['ppl',
#   'live',
#   'w/',
#   '*',
#   '*',
#   '*',
#   '*',
#   'charg',
#   'aggrav',
#   'ault',
#   'bioterror',
#   'thing',
#   'w/',
#   'low',
#   'risk',
#   'transmiss',
#   '.',
#   'hivisnotacrim'],
#  ['howardu',
#   '90blk',
#   '&',
#   'amp',
#   ';',
#   '8wht',
#   'collud',
#   '2',
#   'take',
#   'wht',
#   'f',
#   'usagov',
#   'auth',
#   'hostag',
#   '&',
#   'amp',
#   ';',
#   '2',
#   'make',
#   'look',
#   'blk',
#   'w/bioterror',
#   '&',
#   'amp',
#   ';',
#   'use',
#   'lgl/org',
#   'idi',
#   'id',
#   'still',
#   '?'],
#  ['fight', 'bioterror', 'sir', '.'],
#  ['studi', 'anthrax', 'bioterror', 'befor', '7', '?', '?', 'carpediem'],
#  ['gacourt',
#   '90blk',
#   '&',
#   'amp',
#   ';',
#   '8wht',
#   'collud',
#   '2',
#   'take',
#   'wht',
#   'f',
#   'usagov',
#   'auth',
#   'hostag',
#   '&',
#   'amp',
#   ';',
#   '2',
#   'make',
#   'look',
#   'blk',
#   'w/bioterror',
#   '&',
#   'amp',
#   ';',
#   'use',
#   'lgl/org',
#   'idi',
#   'id',
#   'still',
#   '?'],
#  ['cspanwj',
#   '90blk',
#   '&',
#   'amp',
#   ';',
#   '8wht',
#   'collud',
#   '2',
#   'take',
#   'wht',
#   'f',
#   'usagov',
#   'auth',
#   'hostag',
#   '&',
#   'amp',
#   ';',
#   '2',
#   'make',
#   'look',
#   'blk',
#   'w/bioterror',
#   '&',
#   'amp',
#   ';',
#   'use',
#   'lgl/org',
#   'idi',
#   'id',
#   'still',
#   '?'],
#  ['bioterror',
#   'guidelin',
#   'medic',
#   'public',
#   'health',
#   'manag',
#   'donald',
#   'a.',
#   'hen',
#   '//t.co/tdg0bsmd6c',
#   '//t.co/iirwfzmkho'],
#  ['onu_fr',
#   '74/75',
#   'bioterror',
#   "'",
#   'rockefeller_chi/',
#   "rockefelleruniv'heiress",
#   '2',
#   'evad',
#   'lgl',
#   'effort',
#   '2',
#   'prosecut',
#   'blk',
#   '4',
#   'harvardu',
#   'kidnap',
#   "'",
#   'g',
#   '.',
#   'afp'],
#  ['fight', 'bioterror', 'sir', '.'],
#  ['irand',
#   'onli',
#   'cover',
#   'nuclear',
#   'activ',
#   '.',
#   'bioterror',
#   '?',
#   'iran',
#   'ha',
#   'broken',
#   'least',
#   '27',
#   'agreement',
#   '.'],
#  ['fight', 'bioterror', 'sir', '.'],
#  ['prsnvn',
#   "'s",
#   'good',
#   'hear',
#   '.',
#   'mine',
#   'could',
#   'better',
#   'manag',
#   '.',
#   "'s",
#   'alright',
#   '.',
#   'bioterror',
#   'doe',
#   "n't",
#   'wait',
#   '.'],
#  ['threat', '|', 'anthrax', '|', 'cdc', '//t.co/q6oxzq45v', 'via', 'cdcgov'],
#  ['mariashriv',
#   'wa',
#   "'",
#   "fultoninfo'court",
#   'trip',
#   '2',
#   'keep',
#   'strangers-blk',
#   '&',
#   'amp',
#   ';',
#   'wht-from',
#   'us',
#   "'",
#   'g',
#   'ssapress',
#   'id',
#   '2',
#   'forfeit',
#   '2',
#   'due',
#   '2',
#   'bioterror',
#   'look',
#   '?',
#   'ap'],
#  ['bioterror',
#   'author',
#   'allay',
#   'glander',
#   'fear',
#   'ahead',
#   'rio',
#   'olymp',
#   'equestrian',
#   'test',
#   'event',
#   '//t.co/uotpnsqpz5',
#   'via',
#   'horsetalknz'],
#  ['kaotix_blaz', 'crave', 'u'],
#  ["'ve", 'pool', 'day', 'raisinfing'],
#  ['know',
#   'anyon',
#   'look',
#   'move',
#   'hammond',
#   '?',
#   'share',
#   'thi',
#   'list',
#   '!',
#   '//t.co/3xn1soh4bb'],
#  ['life',
#   'amazin',
#   'time',
#   'crazi',
#   '*',
#   '*',
#   '*',
#   '*',
#   'dey',
#   'wan',
#   'na',
#   'blaze',
#   'hate',
#   'becaus',
#   'made',
#   'took',
#   'wa',
#   'dedic',
#   'n',
#   'motiv'],
#  ['_afrojazz', "'ll", 'add', '(', 'dont', 'even', 'know', 'talk', ')'],
#  ['blaze', 'bro', '//t.co/udkesj01ml'],
#  ['shayoli', 'ye', 'love'],
#  ['see',
#   'virtual',
#   'tour',
#   'one',
#   'list',
#   '547',
#   'fir',
#   'st',
#   'cannon',
#   'beach',
#   'list',
#   'dorri',
#   'caruana',
#   '.',
#   '//t.co/nf46paytvw'],
#  ['never',
#   'got',
#   'paid',
#   'give',
#   '*',
#   '*',
#   '*',
#   '*',
#   '..',
#   'might',
#   'well',
#   'blaze',
#   'anoth',
#   'one'],
#  ['pendleton',
#   'media',
#   'offic',
#   'said',
#   'onli',
#   'fire',
#   'base',
#   'right',
#   'horno',
#   'blaze',
#   '.'],
#  ['welcom',
#   'djryanwolf',
#   'djcoreygrand',
#   'djknyce',
#   'djoneplustwo',
#   'officialcoredj',
#   'famili',
#   'cleveland',
#   'standup',
#   'iamtonyn',
#   '//t.co/p6gqmctglj'],
#  ['love', 'live', '.', 'blaze', 'insid', 'apt', 'balconi'],
#  ['bellalinn', 'alrighti', 'hit', "'ll", 'blaze', '!', '!'],
#  ['blaze',
#   'jay',
#   '*',
#   '*',
#   '*',
#   '*',
#   'dutch',
#   '*',
#   '*',
#   '*',
#   '*',
#   'trade',
#   '.'],
#  ['junesnowpaw', 'yeah', 'gim', 'dat', 'creami', 'white', 'stuff', ';', '3'],
#  ['hair',
#   'poverti',
#   'moment',
#   'need',
#   'get',
#   'fade',
#   'befor',
#   'weekend',
#   'get'],
#  ['properti',
#   'loss',
#   'california',
#   'wildfir',
#   'nearli',
#   'doubl',
#   'week-old',
#   'blaze',
#   'rage',
#   '//t.co/e0uusnpsq5'],
#  ['break',
#   'firefight',
#   'battl',
#   'blaze',
#   'east',
#   'cari',
#   'condo',
#   'build',
#   '//t.co/mim8hh2ce6'],
#  ['*', '*', '*', '*', 'love', 'hate', '.'],
#  ['audacityjamesta',
#   "n't",
#   'like',
#   'babe',
#   '&',
#   'lt',
#   ';',
#   '3',
#   "'ll",
#   'ball',
#   'fun',
#   'lan',
#   '!',
#   ')'],
#  ['reaction', 'determin'],
#  ['port',
#   'coquitlam',
#   'fire',
#   'crew',
#   'say',
#   'electr',
#   'towel',
#   'warmer',
#   'start',
#   'four',
#   'alarm',
#   'blaze',
#   'last',
#   'week',
#   'destroy',
#   'sever',
#   'busi',
#   '.'],
#  ['like',
#   'youtub',
#   'video',
#   'iamrrsb',
#   '//t.co/pdehd1tcpk',
#   'minecraft',
#   'skywar',
#   '-',
#   'blaze',
#   'que',
#   'usa',
#   'hack',
#   'e',
#   'flechada',
#   'sinistra',
#   '!'],
#  ['dem',
#   '.',
#   'blaze',
#   'cover',
#   'month',
#   'ago.chicago',
#   'polic',
#   'detain',
#   'thousand',
#   'black',
#   'american',
#   'interrog',
#   'facil',
#   '//t.co/uwitvbsbnc'],
#  ['yo', 'got', 'bar', "'m", 'even', 'rapper'],
#  ['like',
#   'youtub',
#   'video',
#   'ashen',
#   '//t.co/yc9tywuzqm',
#   'blaze',
#   '/',
#   'atgam',
#   'handheld',
#   'mega',
#   'drive',
#   '|',
#   'ashen'],
#  ['ugh',
#   'blaze',
#   'put',
#   'calori',
#   'pizza',
#   '?',
#   'ok',
#   'cool',
#   'thisispublichealth'],
#  ['pic',
#   'blaze',
#   'fort',
#   'kid',
#   'look',
#   'like',
#   '*',
#   '*',
#   '*',
#   '*',
#   'stuffin',
#   'face',
#   'like',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '//t.co/ae9cpiexak'],
#  ['look',
#   'like',
#   'year',
#   'write',
#   'comput',
#   'ahead',
#   '.',
#   '//t.co/cyxbrzxwq4'],
#  ['beautiful_juic1', 'let', 'know'],
#  ['babysweet420',
#   "'m",
#   'mad',
#   '420',
#   'name',
#   '&',
#   'amp',
#   ';',
#   "n't",
#   'blaze',
#   '.'],
#  ['guiltygearxxacp',
#   'yeah',
#   'know',
#   'blaze',
#   'blue',
#   'dont',
#   'twitter',
#   'lol',
#   'drew',
#   'thi',
#   'week',
#   'ago',
#   '//t.co/sk3l74flzz'],
#  ['socialmedia',
#   'news',
#   '-',
#   'new',
#   'facebook',
#   'page',
#   'featur',
#   'seek',
#   'help',
#   'person',
#   'custom',
#   'experi',
#   '//t.co/nbizatlsmv'],
#  ['djjohnblaz', 'shout', 'blaze', 'hottest', 'dj', 'sothwest'],
#  ['like',
#   'youtub',
#   'video',
#   '//t.co/n95igskd3p',
#   'minecraft',
#   'episod',
#   '2',
#   "'blaze",
#   'farm',
#   'begin',
#   '!',
#   "'"],
#  ['properti',
#   'loss',
#   'california',
#   'wildfir',
#   'nearli',
#   'doubl',
#   'week-old',
#   'blaze',
#   'rage',
#   'fireâ\x89ã\x9b_',
#   '//t.co/msdizftz2g'],
#  ['christycroley',
#   'work',
#   'yet',
#   '.',
#   'see',
#   'new',
#   'vela',
#   'short',
#   'blaze',
#   '?',
#   '//t.co/q8reoevlu'],
#  ['crave', 'slurpe', ';', '-', ';'],
#  ['*',
#   '*',
#   '*',
#   '*',
#   'need',
#   'go',
#   'like',
#   'yesterday',
#   '?',
#   '?',
#   '?',
#   '?',
#   '//t.co/3op6g7ovzo'],
#  ['uabstephenlong',
#   'courtlizcamp',
#   'total',
#   'tweet',
#   'fail',
#   '!',
#   'beauti',
#   'insid',
#   'blaze',
#   '!'],
#  ['ovoiz', 'baddiemoneysign', 'blaze'],
#  ['lithgow',
#   'new',
#   'homeless',
#   'blaze',
#   'near',
#   'portland',
#   '//t.co/cht5w3znik'],
#  ['mixtap', 'come', 'promis', '.', 'goin', 'right', '//t.co/uungrqougn'],
#  ['_itzsteven',
#   'xdojjjj',
#   'whopper_jr_760',
#   'huh',
#   '?',
#   '?',
#   'leo',
#   'start',
#   'last',
#   'year',
#   'ever',
#   'sinc',
#   'peopl',
#   'blaze',
#   'back',
#   '?',
#   '?'],
#  ['blizzard_draco', 'saw', 'let', "'s", 'eat', 'blaze', 'blazinsmash'],
#  ['3',
#   'bedroom',
#   '1',
#   'bath',
#   'sale',
#   '29',
#   'palm',
#   'ca',
#   '.',
#   '(',
#   '//t.co/qms8rressd',
#   ')',
#   '(',
#   'youtub',
#   'video',
#   '...',
#   '//t.co/zla30jcssq'],
#  ['big',
#   'buzzi',
#   'john',
#   'blaze',
#   '.',
#   'ju',
#   'kame',
#   'home',
#   '12',
#   'year',
#   'bid',
#   '.',
#   'lovethyfamili',
#   '//t.co/xreuonzzbi'],
#  ['?', '?', 'ye', '2', 'gun', '?', '?', '?', '?'],
#  ['a__ce', 'daem', 'girl', 'smooth', 'asf', 'c', '?'],
#  ['//t.co/wkv8vqvkt6',
#   'artisteoftheweekfact',
#   'say',
#   'convers',
#   'coast2coastdj',
#   'agre',
#   'crystal_blaz',
#   "'s",
#   'jiwonl',
#   'hiphop',
#   'clubbang'],
#  ['bright',
#   '&',
#   'amp',
#   ';',
#   'blaze',
#   'fireman',
#   'birthday',
#   'parti',
#   '//t.co/9rfo9gy3n',
#   'wed'],
#  ['cruisingblaz', 'bang', '?'],
#  ['real',
#   'vibez',
#   'radio',
#   '-',
#   'blaze',
#   'best',
#   'vibez',
#   '!',
#   '!',
#   '!',
#   '//t.co/emvohm9m6j',
#   'nowplay',
#   'listenl'],
#  ['montgomeri',
#   'come',
#   'blaze',
#   'hot',
#   'weather',
#   '...',
#   'stay',
#   'std',
#   '.',
#   'yet',
#   'anoth',
#   'reject',
#   'citi',
#   'slogan',
#   '.'],
#  ['come',
#   'join',
#   'us',
#   'tomorrow',
#   '!',
#   'august',
#   '7',
#   '2015',
#   'transcend',
#   'blaze',
#   'trail',
#   'diversifi',
#   'world',
#   'market',
#   '...',
#   '//t.co/nr1i8qnao1'],
#  ['morgan',
#   'silver',
#   'dollar',
#   '1880',
#   'gem',
#   'bu',
#   'dmpl',
#   'cameo',
#   'rev',
#   'blaze',
#   'ms+++++',
#   'high',
#   'grade',
#   '!',
#   '-',
#   'full',
#   'read',
#   'â\x89ã\x9b_',
#   '//t.co/iu9bafdxey',
#   '//t.co/aphqu5svet'],
#  ['morgan',
#   'silver',
#   'dollar',
#   '1880',
#   'gem',
#   'bu',
#   'dmpl',
#   'cameo',
#   'rev',
#   'blaze',
#   'ms+++++',
#   'high',
#   'grade',
#   '!',
#   '-',
#   'full',
#   'read',
#   'â\x89ã\x9b_',
#   '//t.co/m96kbqwior',
#   '//t.co/wrjr846fk'],
#  ['thi',
#   'bowl',
#   'got',
#   'think',
#   '...',
#   '*',
#   '*',
#   '*',
#   '*',
#   "'ve",
#   'blaze',
#   '*',
#   '*',
#   '*',
#   '*',
#   'long'],
#  ['danryckert',
#   'drewscanlon',
#   "'s",
#   'blaze',
#   'thi',
#   'game',
#   'best',
#   'stealth',
#   'skill',
#   'yet',
#   '.',
#   'noth',
#   'beat',
#   'silenc',
#   'm4',
#   '.'],
#  ['*',
#   '*',
#   '*',
#   '*',
#   'say',
#   'im',
#   'hot',
#   'say',
#   '*',
#   '*',
#   '*',
#   '*',
#   'im',
#   'blaze'],
#  ['bryanvsbracey',
#   'ustadium',
#   'whi',
#   'need',
#   'blaze',
#   'speed',
#   '?',
#   'think',
#   'watt',
#   'far',
#   'impress',
#   'obj',
#   'anoth',
#   'quick',
#   'littl',
#   'guy'],
#  ['bit',
#   'pacquiao',
#   'vs',
#   'marquez',
#   '3',
#   'unfil',
#   'blaze',
#   'swarm',
#   'onlin',
#   'durvod',
#   '//t.co/6vja8r4yxa'],
#  ['turn',
#   'radio',
#   'stoponesound',
#   'live',
#   'airwav',
#   '//t.co/g7s34sw2am',
#   '&',
#   'amp',
#   ';',
#   '107.9',
#   'fm',
#   'stickynyc',
#   '95root',
#   'blaze',
#   'hit'],
#  ['baseballquotes1', '32', 'inch', 'dynasti'],
#  ["'m",
#   'onli',
#   'weapon',
#   'master',
#   '!',
#   'let',
#   "'s",
#   'go',
#   'gun',
#   'blaze',
#   '!',
#   'hinatobot'],
#  ['blazing_ben',
#   'pattyds50',
#   'gwfraze',
#   'joshuaaraf',
#   'realli',
#   '.',
#   'sadli',
#   'come',
#   'expect',
#   'obama',
#   '.'],
#  ['check', 'blaze', 'hors', 'tattoo', 'yelp', '//t.co/z8nxwmymwa'],
#  ['shouout', 'kasad1lla', 'caus', 'vocal', 'blaze', 'hot', 'like', 'weather'],
#  ['s3xleak',
#   '!',
#   '!',
#   '!',
#   'ph0to',
#   '19yr',
#   'old',
#   'ash',
#   'wo',
#   'ladi',
#   'festac',
#   'town',
#   'delta',
#   'exp0s',
#   'bbm',
#   '5',
#   'leak',
#   'pictur',
#   '...',
#   '//t.co/ixrehm05yq'],
#  ['oh',
#   'heart',
#   'race',
#   'temperatur',
#   'blaze',
#   'roof',
#   'videoveranomtv',
#   'fifth',
#   'harmoni'],
#  ['omgbethersss', 'bethanymota', 'haha', 'love', 'thi', '?', '?'],
#  ...]

# %% [markdown]
# Play around with your data and the processing a little bit more. What happens when you use a lemmer instead of a stemmer? What other stopwords can you exclude? What about removing punctuation?
#
# Now, print out the size of your processed vocabulary. How many words does it have now? Is it fewer or more than the original vocabulary?

# %%
# your code here
len(set([y for x in tweets for y in x]))
# Out:
# 25916

# %% [markdown]
# With these pre-processing steps, we have taken raw tweet data, chopped it up into individual tokens, removed stop words, stemmed, and made it all lower case. This has decreased our vocabulary size by almost 10000 tokens!

# %% [markdown]
# ### Data visualization
#
# Let us visualize the data now. We are going to look at the distribution of the number of words in each tweet. This can be done using a histogram. What is the most common number of words in a tweet? In the process of classifying your dataset, your model may look at factors such as the length of the tweet, the number of words etc. Plotting your data out also helps you to ensure that your code is working, and not throwing out ridiculous numbers.

# %%
import matplotlib.pyplot as plt
def plot_hist(tweets):
    sentence_lengths = [len(tokens) for tokens in tweets]
    fig = plt.figure(figsize=(6, 6)) 
    plt.xlabel('Tweet length')
    plt.ylabel('Number of tweets')
    plt.hist(sentence_lengths, bins=20)
    plt.show()
    return sentence_lengths
tweet_lengths = plot_hist(tweets)

# %% [markdown]
# We can now see that the average tweet has about 12-15 words, and that there are a few with almost 60 words. What exactly is the length of the shortest tweet, the length of the longest tweet, and the average length of all tweets? Print those values out.

# %%
# Your code here
print('minimun: {}, maximum: {}, average: {:.2f}'.format(min(tweet_lengths), max(tweet_lengths), sum(tweet_lengths)/len(tweet_lengths)))
# Out:
# minimun: 1, maximum: 64, average: 12.43

# %% [markdown]
# We are getting to know our data more and more now. Let us dive deeper and see if we can determine if there is a difference in the average length of tweets for relevant and not relevant tweets. Perhaps it can be used as a good feature for future analyis.
#
# To do that, we use the `'choose_one'` column in `df_raw`. If the value in the column is 'Relevant', the tweet is classified as relating to a natural disaster. If the value is 'Not Relevant', the tweet does not relate to a natural disaster.
#
# Can you print out the average length of tweet for relevant tweets, and the average length of tweet for not relevant tweets?
#
# *Hint: the dataframe `df_result` has been constructed to contain the processed tweets and the relevance. create two dataframes, one containing only 'Relevant' tweets, and one containing only 'Not Relevant' tweets. This can be done by subsetting the dataframe: `df_result[df_result['choose_one']=='Relevant']`. We have given an example of how to do it to create a dataframe of positive examples. Can you create the dataframe of negative examples?
#
# *Hint 2: To calculate the length of each tweet, you can use the `.apply(len)` function. You can also use `.mean()` to get the mean of the results.

# %%
df_result = df_raw['choose_one'].copy().to_frame()
df_result['processed_text'] = tweets
df_neg=df_result[df_result['choose_one']=='Not Relevant']
df_pos=df_result[df_result['choose_one']=='Relevant']
print(df_pos['processed_text'].apply(len).mean(), df_neg['processed_text'].apply(len).mean())
# Out:
# 12.748127541194094 12.190237594957168

# %% [markdown]
# Do you think tweet length make a good feature?

# %% [markdown]
# ## Data analysis challenge
#
# Using the skills you have learnt, apply the text processing process on the data you have gathered in the beginning of the notebook (from Wikipedia). Use the knowledge of data scraping and text processing you've gathered here.
#
# Report the initial and final vocabulary size!

# %%
# your code here
tokenized_raw = [nltk.tokenize.word_tokenize(x) for x in all_para] 
print('Initial vocab size {}'.format(len(set([y for x in tokenized_raw for y in x]))))

# %%
x = pd.DataFrame({'text':all_para}, index = [1])
processed_all_para = tokenizer(x)
print('Final vocab size {}'.format(len(set([y for x in processed_all_para for y in x]))))

# %% [markdown]
# We have now learnt:
# 1. How to look for text data
# 2. How to collect data online using scrapers and various modules
# 3. How to save this data onto your computer
# 4. How to process this text data into a form your computer can understand
# 5. How to analyze and visualize the processed data
#
# In the next module, we will learn how to take what we have learnt and use it to train an NLP model to actually recognize tweets!
