# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# NLTK Text Datasets are called corpora

# %%
from nltk.book import *
text1
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908
# <Text: Moby Dick by Herman Melville 1851>

# %%
text1.dispersion_plot(["Moby","Dick","Monstrous","gone","life","whale"])

# %%
len(text1)
# Out:
# 260819

# %%
set(text1)
# Out:
# {'Mississippi',
#  'retentive',
#  'wigwams',
#  'Measured',
#  'creativeness',
#  'lone',
#  'extermination',
#  'WHALEBONE',
#  'despised',
#  'Vice',
#  'abundantly',
#  '),',
#  'quoin',
#  'imbecility',
#  'pricking',
#  'inspire',
#  'favourite',
#  'exhaustion',
#  'Blast',
#  'ears',
#  'carcass',
#  'Monsieurs',
#  'goddess',
#  'tending',
#  'YORK',
#  'eminent',
#  'softest',
#  'lunar',
#  'APPLICATION',
#  'balena',
#  'hag',
#  'licked',
#  'Creagh',
#  'sultanism',
#  'drills',
#  'voice',
#  'partitioned',
#  'shines',
#  'Mexico',
#  'unlacing',
#  'beaks',
#  'Zealand',
#  'HELM',
#  'Human',
#  'CHEERLY',
#  'Horse',
#  'sailings',
#  'unrestingly',
#  'Lightning',
#  'garrison',
#  'knell',
#  'GREENLAND',
#  'drive',
#  'presumable',
#  'grindstone',
#  'nursery',
#  'spasmodic',
#  'Pippin',
#  'complacent',
#  'fierceness',
#  'devil',
#  'appearing',
#  'conveyed',
#  'size',
#  'swarthy',
#  'intolerableness',
#  'Spanishly',
#  'trapped',
#  'Bethink',
# ...

# %%
sorted(set(text1))
# for sorting in order characters first, then no.s then spellings
# Out:
# ['!',
#  '!"',
#  '!"--',
#  "!'",
#  '!\'"',
#  '!)',
#  '!)"',
#  '!*',
#  '!--',
#  '!--"',
#  "!--'",
#  '"',
#  '"\'',
#  '"--',
#  '"...',
#  '";',
#  '$',
#  '&',
#  "'",
#  "',",
#  "',--",
#  "'-",
#  "'--",
#  "';",
#  '(',
#  ')',
#  '),',
#  ')--',
#  ').',
#  ').--',
#  '):',
#  ');',
#  ');--',
#  '*',
#  ',',
#  ',"',
#  ',"--',
#  ",'",
#  ",'--",
#  ',)',
#  ',*',
#  ',--',
#  ',--"',
#  ",--'",
#  '-',
#  '--',
#  '--"',
#  "--'",
#  '--\'"',
#  '--(',
#  '---"',
#  '---,',
#  '.',
#  '."',
#  '."*',
#  '."--',
#  ".'",
#  '.\'"',
#  '.)',
#  '.*',
#  '.*--',
#  '.,',
#  '.--',
#  '.--"',
#  '...',
#  '....',
#  '.]',
#  '000',
#  '1',
#  '10',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '11',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '12',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '13',
# ...

# %%
len(set(text1))
# Out:
# 19317

# %%
text1.count("Moby")
# Out:
# 84

# %%
100* text1.count("Moby") / len(text1)
# Out:
# 0.032206242643365704

# %%
100* text1.count("and") / len(text1)
# Out:
# 2.3096476867099405

# %%
sent1 = ["My","name","is"] + ["Ansh","."]
sent1
# Out:
# ['My', 'name', 'is', 'Ansh', '.']

# %%
text1.index("god")
# Out:
# 34621

# %%
list_numbers=[3,1,2,3,3,4,5,6,3,7,8,9,10]
[i for i,n in enumerate(list_numbers) if n == 3]
#list comprehension or enumerate
# Out:
# [0, 3, 4, 8]

# %%
[i for i,n in enumerate(text1) if n == "monstrous"]
# Out:
# [899, 1176, 9530, 9594, 32717, 96103, 124761, 124777, 165681, 209645]

# %%
text1[16715:16735]
# Out:
# ['in',
#  'dreams',
#  '--',
#  'I',
#  'opened',
#  'my',
#  'eyes',
#  ',',
#  'and',
#  'the',
#  'before',
#  'sun',
#  '-',
#  'lit',
#  'room',
#  'was',
#  'now',
#  'wrapped',
#  'in',
#  'outer']

# %%
fdist1 = FreqDist(text1)
print(fdist1)
#(word,frequency)
# Out:
# <FreqDist with 19317 samples and 260819 outcomes>

# %%
fdist1.most_common()
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624),
#  ('The', 612),
#  ('their', 612),
#  ('are', 586),
#  ('they', 586),
#  ('an', 582),
#  ('some', 578),
#  ('then', 571),
# ...

# %%
fdist1.most_common(50)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624)]

# %%
fdist1.most_common()[-190202:-19000]
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624),
#  ('The', 612),
#  ('their', 612),
#  ('are', 586),
#  ('they', 586),
#  ('an', 582),
#  ('some', 578),
#  ('then', 571),
# ...

# %%
fdist1["whale"] #no.of times it occurs
# Out:
# 906

# %%
fdist1.plot(50,cumulative=True)  #top 50 words
# Out:
# <Axes: xlabel='Samples', ylabel='Cumulative Counts'>

# %%
fdist1.plot(50,cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>
